# %%
import numpy as np
import argparse
import cv2

from tqdm import tqdm
import sys
sys.path.append("/Users/rcarlson/Documents/GitHub/lasagna3/snakes")
import mahotas
from ops.imports_ipython import *
from scipy.spatial.distance import cdist


import skimage
import tensorflow as tf
# Out:
# /home/rcarlson/OpticalPooledScreens/ops/annotate.py:20: UserWarning: visitor font not found at /home/rcarlson/OpticalPooledScreens/ops/visitor1.ttf
#   warnings.warn('visitor font not found at {0}'.format(VISITOR_PATH))

# %%
df = pd.read_hdf('/home/rcarlson/mountb/mergehdfs2/dfall_key_nona.hdf')

# %%
df.loc[:,df.columns.str.startswith("dapi")]
# Out:
#           dapi_corrch1_nuclear_corr  dapi_corrch2_nuclear_corr  \
# 1                          0.825456                   0.941051
# 2                          0.383439                   0.514844
# 3                          0.781937                   0.915194
# 4                         -0.608751                   0.876683
# 5                         -0.251165                   0.008873
# ...                             ...                        ...
# 10605514                   0.556273                   0.712087
# 10605515                  -0.553204                  -0.173183
# 10605516                  -0.055369                   0.293678
# 10605517                   0.411618                   0.791005
# 10605518                  -0.236385                   0.426923
#
#           dapi_corrch3_nuclear_corr  dapi_corrch4_nuclear_corr  \
# 1                          0.888915                  -0.291652
# 2                          0.311178                   0.023699
# 3                          0.746572                  -0.411696
# 4                          0.577062                  -0.755424
# 5                         -0.364610                  -0.313472
# ...                             ...                        ...
# 10605514                   0.536526                  -0.460566
# 10605515                  -0.542576                  -0.345997
# 10605516                   0.061933                   0.006356
# 10605517                   0.580522                  -0.327935
# 10605518                  -0.138199                  -0.492976
#
#           dapi_corrch5_nuclear_corr  dapi_corrch6_nuclear_corr  \
# 1                         -0.202854                  -0.179432
# 2                          0.173520                   0.034548
# 3                         -0.090782                   0.448206
# 4                         -0.776978                  -0.450777
# 5                         -0.303239                  -0.132522
# ...                             ...                        ...
# 10605514                  -0.468065                   0.183910
# 10605515                  -0.429596                  -0.241242
# 10605516                  -0.273385                   0.189908
# 10605517                  -0.597198                   0.260713
# 10605518                  -0.493697                   0.119581
#
#           dapi_nuclear_mean  dapi_nuclear_median  dapi_nuclear_int  \
# 1               9593.665039              10104.0           4614553
# 2               3219.816406               3279.0           1577710
# 3              10268.973633              10560.0           3891941
# 4               9521.233398               9717.0           4693968
# 5               9399.060547               9792.0           4050995
# ...                     ...                  ...               ...
# 10605514        5432.056641               5400.0           2292328
# 10605515        7437.725586               7344.0           2357759
# 10605516        5019.064941               5033.0           3869699
# 10605517        5405.458008               5411.5           2432456
# 10605518        6957.755859               7012.0           4077245
#
#           dapi_nuclear_min  ...  dapi_pftas_cyto45  dapi_pftas_cyto46  \
# 1                     4448  ...           0.000000           0.668067
# 2                     1310  ...           0.000000           0.646789
# 3                     4884  ...           0.000000           0.571429
# 4                     4972  ...           0.000000           0.475285
# 5                     4477  ...           0.000000           0.484848
# ...                    ...  ...                ...                ...
# 10605514              2828  ...           0.000000           0.579167
# 10605515              3676  ...           0.001938           0.631769
# 10605516              2560  ...           0.002611           0.678733
# 10605517              2820  ...           0.000000           0.544236
# 10605518              3606  ...           0.000000           0.658333
#
#           dapi_pftas_cyto47  dapi_pftas_cyto48  dapi_pftas_cyto49  \
# 1                  0.096639           0.063025           0.088235
# 2                  0.105505           0.082569           0.064220
# 3                  0.121693           0.074074           0.121693
# 4                  0.144487           0.114068           0.129278
# 5                  0.060606           0.045455           0.318182
# ...                     ...                ...                ...
# 10605514           0.108333           0.108333           0.100000
# 10605515           0.083032           0.079422           0.093863
# 10605516           0.097285           0.072398           0.070136
# 10605517           0.152815           0.101877           0.088472
# 10605518           0.111111           0.069444           0.072222
#
#           dapi_pftas_cyto50  dapi_pftas_cyto51  dapi_pftas_cyto52  \
# 1                  0.046218           0.033613           0.004202
# 2                  0.077982           0.022936           0.000000
# 3                  0.074074           0.021164           0.010582
# 4                  0.076046           0.049430           0.011407
# 5                  0.075758           0.015152           0.000000
# ...                     ...                ...                ...
# 10605514           0.029167           0.037500           0.016667
# 10605515           0.079422           0.032491           0.000000
# 10605516           0.047511           0.020362           0.009050
# 10605517           0.061662           0.040214           0.000000
# 10605518           0.036111           0.025000           0.025000
#
#           dapi_pftas_cyto53  dapi_pftas_cyto54
# 1                  0.000000           0.000000
# 2                  0.000000           0.000000
# 3                  0.000000           0.005291
# 4                  0.000000           0.000000
# 5                  0.000000           0.000000
# ...                     ...                ...
# 10605514           0.020833           0.000000
# 10605515           0.000000           0.000000
# 10605516           0.002262           0.002262
# 10605517           0.005362           0.005362
# 10605518           0.002778           0.000000
#
# [10368204 rows x 284 columns]

# %%
maxes = list(df.loc[:,df.columns.str.endswith("cell_max")].quantile(.995))

# %%
(maxes)
# Out:
# [16945.0, 36575.984999999404, 23873.0, 14054.0, 62946.0, 35087.0, 50155.0]

# %%
df = pd.read_hdf('/home/rcarlson/mountb/mergehdfs2/dfnew_dropped_corrssover08')


def f(x):
    d = {}
    d['min_dist'] = np.partition(cdist(x[['i','j']].values, x[['i','j']].values),1,axis=1)[:,1]
    d['cell'] = x['cell']
    d['plate'] = x['plate']
    d['gene_symbol'] = x['gene_symbol']
    d['cell_barcode_0'] = x['cell_barcode_0']
    d['i'] = x['i']
    d['j'] = x['j']

    return pd.DataFrame([d['min_dist'],d['cell'],d['gene_symbol'],d['cell_barcode_0'],d['i'],d['j']]).transpose()#pd.Series(d, index=['min_dist','cell'])

# %%
tmp = df.iloc[:,:10].copy()
to_keep = tmp.groupby(['plate','well','site']).cell.count().loc[lambda x: x>1].reset_index()
tmp = pd.merge(tmp, to_keep, how = 'right', on = ['plate','well','site'])

# %%
tmp.shape[0]/df.shape[0] # kept vast majority of cells
# Out:
# 0.9999326670132997

# %%
tmp['cell'] = tmp['cell_x']
tmp = (tmp
       .groupby(['plate','well','site'])
       .apply(f).reset_index())


 
tmp.drop('level_3',inplace = True, axis=1)
tmp.columns = ['plate','well','Site','min_dist','cell','gene','cell_barcode_0','i','j']

# %%
tmp[tmp.min_dist > 13].shape[0]/tmp.shape[0] ## keep ~88% of cells, aim to keep single-cell crop 26x26 ish
# Out:
# 0.8881839244307085

# %%
df_26 = tmp[tmp.min_dist > 13]

grped = df_26.groupby(['cell_barcode_0']).count()
few_cells = list(grped[grped.cell < 25].index)
print(len(few_cells))
df_26 = df_26[~df_26.cell_barcode_0.isin(few_cells)]

df_26.to_hdf('/home/rcarlson/mountb/m40-m42/df_26.hdf',key='x')

# %%
df_26 = pd.read_hdf('/home/rcarlson/mountb/m40-m42/df_26.hdf')

# %%
og_ij = pd.read_hdf('/home/rcarlson/mountb/mergehdfs2/dfall.hdf')

# %%
og_ij[['plate', 'well', 'site','cell', 'i', 'j']].to_hdf('/home/rcarlson/mountb/mergehdfs2/dfall_ijonly.hdf', key = 'x')

# %%
df_26['site'] = df_26.Site
og_ij = pd.read_hdf('/home/rcarlson/mountb/mergehdfs2/dfall_ijonly.hdf')

# %%
#, start = 0, stop = 5,  columns =  ['plate', 'well', 'site', 'i', 'j'])
df_26 = pd.merge(df_26, og_ij, on = ['plate', 'well', 'site', 'cell'], how = 'left')

# %%
df_26['i'] = df_26.i_y
df_26['j'] = df_26.j_y
df_26.to_hdf('/home/rcarlson/mountb/m40-m42/df_26.hdf',key='x')
# Out:
# /home/rcarlson/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py:2620: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block2_values] [items->Index(['plate', 'well', 'min_dist', 'cell', 'gene', 'cell_barcode_0', 'i_x',
#        'j_x'],
#       dtype='object')]
#
#   encoding=encoding,

# %%
df_26 = pd.read_hdf('/home/rcarlson/mountb/m40-m42/df_26.hdf')

# %%
from natsort import natsorted 
def save_singlecells_crop(plate, well, nchannels, df_cells_interest, dist_from_center = 23):
    border_ct = 0
      # loc only for purposes of defining sites/wells of interest
    # df should contain all cells of interest with i/j indices
    df_cells_interest = df_cells_interest.query('plate == @plate & well == @well')
    files = natsorted(glob('/home/rcarlson/mountb/%s/Well%s*.aligned.tif'%(plate, well)))
    site_list = []
    wells = []
    sites = []
    for n in range(len(files)):
        well = re.findall("/(.*)_site(.*)", (files)[n])[0][0].split('Well')[-1]
        site = re.findall("/(.*)_site(.*)", (files)[n])[0][1].split('.')[0]
        wells.append(well)
        sites.append(site)
        site_list.append([str(well) + '_site' + str(site)+'.'])
    
    cellct = 0
    mastercellct = 0

    
    print('# sites')
    print(len(site_list))
    for z in range(len(site_list)):
        print(mastercellct)
        print(site_list[z])
        well = wells[z]
        site = int(sites[z])
        file =  read('/home/rcarlson/mountb/%s/Well%s_site%s.aligned.tif' %(plate, well, site))
        tmp = df_cells_interest[(df_cells_interest.well == well) & (df_cells_interest.Site == site)]
        ils = list(tmp.i.apply(int))
        jls = list(tmp.j.apply(int))
        cells = list(tmp.cell)
        for i in range((tmp.shape[0])):
            
            
            bounds_cell = np.array((ils[i]-dist_from_center,ils[i]+dist_from_center,
                                    jls[i]-dist_from_center,jls[i]+dist_from_center))
            if (sum(bounds_cell < 0) != 0) | (sum(bounds_cell > 1480) != 0):
                continue # ignore cells on border
                border_ct += 1
            
            cellct += 1
            mastercellct += 1

            tosave = file[:,bounds_cell[0]:bounds_cell[1],bounds_cell[2]:bounds_cell[3]][0:nchannels].astype('float32')
            
            for ch in range(nchannels):
                image_resized = skimage.transform.resize(tosave[ch], (64, 64),
                               anti_aliasing=True, mode = 'constant').astype('float32')
                f = name({}, ext = "ch%s.tif"%ch, mag = "%s_%s"%(plate, cells[i]), well = well, site = site, 
                subdir = "/home/rcarlson/mountb/m40-m42/process/og_single_crops")
                print(np.array([image_resized]).shape)
                save(f, tosave[ch])


                
        read.reset

# %%
plate = "M40A"
for well in ["A1"]:

    save_singlecells_crop(
                 plate = plate,
                 nchannels = 7, well = well, 
                df_cells_interest = df_26.query('well == @well & site < 30'))
# Out:
# # sites
# 1281
# 0
# ['A1_site0.']
# 53
# ['A1_site1.']
# 252
# ['A1_site2.']
# 318
# ['A1_site3.']
# 479
# ['A1_site4.']
# 511
# ['A1_site5.']
# 664
# ['A1_site6.']
# 687
# ['A1_site7.']
# 740
# ['A1_site8.']
# 740
# ['A1_site9.']
# 757
# ['A1_site10.']
# 757
# ['A1_site11.']
# 826
# ['A1_site12.']
# 829
# ['A1_site13.']
# 887
# ['A1_site14.']
# 887
# ['A1_site15.']
# 944
# ['A1_site16.']
# 969
# ['A1_site17.']
# 1094
# ['A1_site18.']
# 1094
# ['A1_site19.']
# 1094
# ['A1_site20.']
# 1217
# ['A1_site21.']
# 1248
# ['A1_site22.']
# 1406
# ['A1_site23.']
# 1417
# ['A1_site24.']
# 1579
# ['A1_site25.']
# 1600
# ['A1_site26.']
# 1748
# ['A1_site27.']
# 1748
# ['A1_site28.']
# 1893
# ['A1_site29.']
# 1925
# ['A1_site30.']
# 1925
# ['A1_site31.']
# 1925
# ['A1_site32.']
# 1925
# ['A1_site33.']
# 1925
# ['A1_site34.']
# 1925
# ['A1_site35.']
# 1925
# ['A1_site36.']
# 1925
# ['A1_site37.']
# 1925
# ['A1_site38.']
# 1925
# ['A1_site39.']
# 1925
# ['A1_site40.']
# 1925
# ['A1_site41.']
# 1925
# ['A1_site42.']
# 1925
# ['A1_site43.']
# 1925
# ['A1_site44.']
# 1925
# ['A1_site45.']
# 1925
# ['A1_site46.']
# 1925
# ['A1_site47.']
# 1925
# ['A1_site48.']
# 1925
# ['A1_site49.']
# 1925
# ['A1_site50.']
# 1925
# ['A1_site51.']
# 1925
# ['A1_site52.']
# 1925
# ['A1_site53.']
# 1925
# ['A1_site54.']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0d5f011c6981> in <module>
#       5                  plate = plate,
#       6                  nchannels = 7, well = well,
# ----> 7                 df_cells_interest = df_26.query('well == @well & site < 30'))
#
# <ipython-input-9-e93f29767360> in save_singlecells_crop(plate, well, nchannels, df_cells_interest, dist_from_center)
#      27         well = wells[z]
#      28         site = int(sites[z])
# ---> 29         file =  read('/home/rcarlson/mountb/%s/Well%s_site%s.aligned.tif' %(plate, well, site))
#      30         tmp = df_cells_interest[(df_cells_interest.well == well) & (df_cells_interest.Site == site)]
#      31         ils = list(tmp.i.apply(int))
#
# <decorator-gen-118> in read_stack(filename, copy)
#
# ~/OpticalPooledScreens/ops/utils.py in _memoize(f, *args, **kwargs)
#      45 def _memoize(f, *args, **kwargs):
#      46     if not f.keys['active']:
# ---> 47         return f(*args, **kwargs)
#      48
#      49     key = str(args) + str(kwargs)
#
# ~/OpticalPooledScreens/ops/io.py in read_stack(filename, copy)
#      84     """Read a .tif file into a numpy array, with optional memory mapping.
#      85     """
# ---> 86     data = imread(filename, multifile=False, is_ome=False)
#      87     # preserve inner singleton dimensions
#      88     while data.shape[0] == 1:
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in imread(files, **kwargs)
#     608     if isinstance(files, basestring) or hasattr(files, 'seek'):
#     609         with TiffFile(files, **kwargs_file) as tif:
# --> 610             return tif.asarray(**kwargs)
#     611     else:
#     612         with TiffSequence(files, **kwargs_seq) as imseq:
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in asarray(self, key, series, out, validate, maxworkers)
#    2154                                       maxworkers=maxworkers)
#    2155         else:
# -> 2156             result = stack_pages(pages, out=out, maxworkers=maxworkers)
#    2157
#    2158         if result is None:
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in stack_pages(pages, out, maxworkers, **kwargs)
#    9835     if maxworkers < 2:
#    9836         for i, page in enumerate(pages):
# -> 9837             func(page, i)
#    9838     else:
#    9839         # TODO: add exception handling
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in func(page, index, out, filecache, kwargs)
#    9830             filecache.open(page.parent.filehandle)
#    9831             out[index] = page.asarray(lock=filecache.lock, reopen=False,
# -> 9832                                       validate=False, **kwargs)
#    9833             filecache.close(page.parent.filehandle)
#    9834
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in asarray(self, *args, **kwargs)
#    4859             raise RuntimeError('keyframe not set')
#    4860         kwargs['validate'] = False
# -> 4861         return TiffPage.asarray(self, *args, **kwargs)
#    4862
#    4863     def asrgb(self, *args, **kwargs):
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in asarray(self, out, squeeze, lock, reopen, maxsize, maxworkers, validate)
#    4005             with lock:
#    4006                 fh.seek(offsets[0])
# -> 4007                 result = fh.read_array(typecode, product(shape), out=out)
#    4008             if lsb2msb:
#    4009                 bitorder_decode(result, out=result)
#
# ~/OpticalPooledScreens/ops/external/tifffile_new.py in read_array(self, dtype, count, out)
#    5610             raise ValueError('size mismatch')
#    5611
# -> 5612         n = fh.readinto(result)
#    5613         if n != size:
#    5614             raise ValueError('failed to read %i bytes' % size)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Run pretrained network

# %%
from keras.applications import imagenet_utils
from keras.applications import Xception # TensorFlow ONLY

from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img

from keras.models import Model

# Source model
model = Xception(weights = 'imagenet')

# remove last layer
bottleneck_model = Model(inputs=model.input, outputs=model.get_layer('avg_pool').output)
print(bottleneck_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %%
import gc

def preprocess_img(imgname):
        print(imgname)
        imgs = (read(imgname))
        print(imgs.shape)
        mean = imgs.mean(axis = (1,2))
        sd = imgs.std(axis = (1,2))
        mins = imgs.min(axis = (1,2))
        maxs = imgs.max(axis = (1,2))
        
        mean = np.mean(mean)
        sd = np.mean(sd)
        
        print('mean, sd')
        print(mean, sd)
        
        imgs = (imgs - mean)/sd

        imlist = []
        for i in range(imgs.shape[0]):
            if i % 500 == 0:
                print(i)
            img = imgs[i] - mins[i]
            img = img * 255/maxs[i]
            img = np.expand_dims(img, axis = -1)
            img = np.repeat(img, 3, axis = -1)
            img = keras.applications.xception.preprocess_input(img)
            img = np.expand_dims(img,axis = 0)
            imlist.append(img)
        
        print('preprocessing done')

        return imlist
    
def predict_features(imgs):
    imgs = tf.data.Dataset.from_tensor_slices(imgs)
    print('tf dataset created')
    features = bottleneck_model.predict(imgs, use_multiprocessing = True, batch_size = 100, verbose = 1, workers = 2)
    return features


from tqdm.contrib.concurrent import process_map
import keras
def batch_preprocess_predict(file, start, end, plate, well):
    imgs = preprocess_img(file)
    print(len(imgs))

    feats = predict_features(imgs)
    (pd.DataFrame(feats)
        .to_pickle('/home/rcarlson/mountb/m40-m42/process/xception/feats_'+plate+'_'+well+'_'+str(start)+'_'+str(end)+'.ch'+str(channel)+'.pkl'))

# %%
from natsort import natsorted 
def save_singlecells_finish(plate, well, start, nchannels, df_cells_interest, dist_from_center = 23):
    border_ct = 0
      # loc only for purposes of defining sites/wells of interest
    # df should contain all cells of interest with i/j indices
    df_cells_interest = df_cells_interest.query('plate == @plate & well == @well')
    files = natsorted(glob('/home/rcarlson/mountb/%s/Well%s*.aligned.tif'%(plate, well)))
    site_list = []
    wells = []
    sites = []
    for n in range(len(files)):
        well = re.findall("/(.*)_site(.*)", (files)[n])[0][0].split('Well')[-1]
        site = re.findall("/(.*)_site(.*)", (files)[n])[0][1].split('.')[0]
        wells.append(well)
        sites.append(site)
        site_list.append([str(well) + '_site' + str(site)+'.'])
    
    cellct = 0
    mastercellct = start
    cells2k = []
    savels = []
    
    print('# sites')
    print(len(site_list))
    for z in range(len(site_list)):
        print(mastercellct)
        print(site_list[z])
        well = wells[z]
        site = int(sites[z])
        if site not in pd.unique(df_cells_interest.site):
            continue
        file =  read('/home/rcarlson/mountb/%s/Well%s_site%s.aligned.tif' %(plate, well, site))
        tmp = df_cells_interest[(df_cells_interest.well == well) & (df_cells_interest.Site == site)]
        ils = list(tmp.i.apply(int))
        jls = list(tmp.j.apply(int))
        cells = list(tmp.cell)
        for i in range((tmp.shape[0])):
            bounds_cell = np.array((ils[i]-dist_from_center,ils[i]+dist_from_center,
                                    jls[i]-dist_from_center,jls[i]+dist_from_center))
            if (sum(bounds_cell < 0) != 0) | (sum(bounds_cell > 1480) != 0):
                continue # ignore cells on border
                border_ct += 1
            
            cellct += 1
            mastercellct += 1

            tosave = file[:,bounds_cell[0]:bounds_cell[1],bounds_cell[2]:bounds_cell[3]][0:nchannels].astype('float32')
            
            ### RESIZE ###
            
            image_resized0 = skimage.transform.resize(tosave[0], (299 , 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')
            image_resized1 = skimage.transform.resize(tosave[1], (299, 299),
                                 anti_aliasing=True, mode = 'constant').astype('float32')
            image_resized2 = skimage.transform.resize(tosave[2], (299, 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')
            image_resized3 = skimage.transform.resize(tosave[3], (299, 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')           
            image_resized4 = skimage.transform.resize(tosave[4], (299, 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')
            image_resized5 = skimage.transform.resize(tosave[5], (299, 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')
            image_resized6 = skimage.transform.resize(tosave[6], (299, 299),
                               anti_aliasing=True, mode = 'constant').astype('float32')
            
            tosave = np.array((image_resized0,image_resized1,image_resized2,image_resized3,image_resized4,
                              image_resized5,image_resized6))
            cells2k.append(tosave)
            
            savename = '/home/rcarlson/mountb/%s/Well%s_site%s.aligned.tif' %(plate, well, site) + "_%s.cell" %(cells[i])
            savels.append(savename)

            if cellct == 2000:
                cells2k = np.array(cells2k)
                print('saving')
                
                f = name({}, ext = "ch", mag = "%s_%s_%s"%(plate, mastercellct-cellct,
                                                                                    mastercellct), well = well, site = site, 
                     subdir = "/home/rcarlson/mountb/m40-m42/process/single_cells")
                
                
                for ch in range(cells2k.shape[1]):
                    print(f + str(ch) + '.tif')
                    save(f + str(ch) + '.tif', cells2k[:,ch,:,:])
                  
                pd.Series(savels).to_csv("/home/rcarlson/mountb/m40-m42/process/cells_ls/%s_%s_%s_%s.csv"%(plate, well, mastercellct-cellct,mastercellct))
                savels = []
                cells2k = []
                cellct = 0

            print(tmp.shape)
            if (z == len(site_list)-1) & (i == tmp.shape[0]-1):
                cells2k = np.array(cells2k)
                print('saving last site and cell')
                f = name({}, ext = "ch", mag = "%s_%s_%s"%(plate, mastercellct-cellct,
                                                                                    mastercellct), well = well, site = site, 
                     subdir = "/home/rcarlson/mountb/m40-m42/process/single_cells")
                
                for ch in range(cells2k.shape[1]):
                    save(f + str(ch) + '.tif', cells2k[:,ch,:,:])
                
                pd.Series(savels).to_csv("/home/rcarlson/mountb/m40-m42/process/cells_ls/%s_%s_%s_%s.csv"%(plate, well, mastercellct-cellct,mastercellct))
                
                print(np.array(cells2k).shape)

                
        read.reset

# %%
ix = df_26.query('well == @well & plate == @plate & site == @site & cell == @cell').index[0]
ofint = df_26.copy().query('well == @well & plate == @plate').iloc[ix+1:,:]
ofint.head()
# Out:
# Empty DataFrame
# Columns: [plate, well, Site, min_dist, cell, gene, cell_barcode_0, i_x, j_x, site, i_y, j_y, i, j]
# Index: []

# %%
plate = "M40A"
for well in ["B1"]:#,"A3","B1","B2","B3"]:

    save_singlecells(
                 plate = plate,
                 nchannels = 7, well = well, 
                df_cells_interest = df_26.query('well == @well'))
# Out:
# # sites
# 1281
# 0
# ['B1_site0.']
# 44
# ['B1_site1.']
# 145
# ['B1_site2.']
# 173
# ['B1_site3.']
# 304
# ['B1_site4.']
# 364
# ['B1_site5.']
# 377
# ['B1_site6.']
# 401
# ['B1_site7.']
# 504
# ['B1_site8.']
# 538
# ['B1_site9.']
# 724
# ['B1_site10.']
# 754
# ['B1_site11.']
# 821
# ['B1_site12.']
# 821
# ['B1_site13.']
# 911
# ['B1_site14.']
# 911
# ['B1_site15.']
# 1037
# ['B1_site16.']
# 1053
# ['B1_site17.']
# 1093
# ['B1_site18.']
# 1093
# ['B1_site19.']
# 1182
# ['B1_site20.']
# 1547
# ['B1_site21.']
# 1766
# ['B1_site22.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_0_2000_B1_Site-22.ch6.tif
# 2003
# ['B1_site23.']
# 2081
# ['B1_site24.']
# 2291
# ['B1_site25.']
# 2357
# ['B1_site26.']
# 2544
# ['B1_site27.']
# 2602
# ['B1_site28.']
# 2807
# ['B1_site29.']
# 2876
# ['B1_site30.']
# 3086
# ['B1_site31.']
# 3209
# ['B1_site32.']
# 3490
# ['B1_site33.']
# 3645
# ['B1_site34.']
# 3993
# ['B1_site35.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_2000_4000_B1_Site-35.ch6.tif
# 4150
# ['B1_site36.']
# 4465
# ['B1_site37.']
# 4624
# ['B1_site38.']
# 4653
# ['B1_site39.']
# 4940
# ['B1_site40.']
# 5076
# ['B1_site41.']
# 5359
# ['B1_site42.']
# 5395
# ['B1_site43.']
# 5608
# ['B1_site44.']
# 5648
# ['B1_site45.']
# 5893
# ['B1_site46.']
# 5899
# ['B1_site47.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_4000_6000_B1_Site-47.ch6.tif
# 6090
# ['B1_site48.']
# 6090
# ['B1_site49.']
# 6245
# ['B1_site50.']
# 6250
# ['B1_site51.']
# 6396
# ['B1_site52.']
# 6463
# ['B1_site53.']
# 6656
# ['B1_site54.']
# 6738
# ['B1_site55.']
# 6979
# ['B1_site56.']
# 7069
# ['B1_site57.']
# 7256
# ['B1_site58.']
# 7590
# ['B1_site59.']
# 7774
# ['B1_site60.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_6000_8000_B1_Site-60.ch6.tif
# 8097
# ['B1_site61.']
# 8270
# ['B1_site62.']
# 8587
# ['B1_site63.']
# 8804
# ['B1_site64.']
# 9057
# ['B1_site65.']
# 9145
# ['B1_site66.']
# 9368
# ['B1_site67.']
# 9454
# ['B1_site68.']
# 9683
# ['B1_site69.']
# 9817
# ['B1_site70.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_8000_10000_B1_Site-70.ch6.tif
# 10057
# ['B1_site71.']
# 10230
# ['B1_site72.']
# 10538
# ['B1_site73.']
# 10741
# ['B1_site74.']
# 11104
# ['B1_site75.']
# 11348
# ['B1_site76.']
# 11675
# ['B1_site77.']
# 11860
# ['B1_site78.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_10000_12000_B1_Site-78.ch6.tif
# 12192
# ['B1_site79.']
# 12320
# ['B1_site80.']
# 12598
# ['B1_site81.']
# 12720
# ['B1_site82.']
# 12974
# ['B1_site83.']
# 12989
# ['B1_site84.']
# 13140
# ['B1_site85.']
# 13156
# ['B1_site86.']
# 13353
# ['B1_site87.']
# 13453
# ['B1_site88.']
# 13719
# ['B1_site89.']
# 13851
# ['B1_site90.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_12000_14000_B1_Site-90.ch6.tif
# 14188
# ['B1_site91.']
# 14344
# ['B1_site92.']
# 14651
# ['B1_site93.']
# 14762
# ['B1_site94.']
# 15083
# ['B1_site95.']
# 15226
# ['B1_site96.']
# 15497
# ['B1_site97.']
# 15602
# ['B1_site98.']
# 15786
# ['B1_site99.']
# 15893
# ['B1_site100.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_14000_16000_B1_Site-100.ch6.tif
# 16082
# ['B1_site101.']
# 16115
# ['B1_site102.']
# 16333
# ['B1_site103.']
# 16405
# ['B1_site104.']
# 16661
# ['B1_site105.']
# 16719
# ['B1_site106.']
# 16974
# ['B1_site107.']
# 17047
# ['B1_site108.']
# 17304
# ['B1_site109.']
# 17323
# ['B1_site110.']
# 17541
# ['B1_site111.']
# 17681
# ['B1_site112.']
# 17929
# ['B1_site113.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_16000_18000_B1_Site-113.ch6.tif
# 18107
# ['B1_site114.']
# 18369
# ['B1_site115.']
# 18552
# ['B1_site116.']
# 18883
# ['B1_site117.']
# 19031
# ['B1_site118.']
# 19310
# ['B1_site119.']
# 19496
# ['B1_site120.']
# 19822
# ['B1_site121.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_18000_20000_B1_Site-121.ch6.tif
# 20035
# ['B1_site122.']
# 20375
# ['B1_site123.']
# 20565
# ['B1_site124.']
# 20930
# ['B1_site125.']
# 21137
# ['B1_site126.']
# 21526
# ['B1_site127.']
# 21793
# ['B1_site128.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_20000_22000_B1_Site-128.ch6.tif
# 22165
# ['B1_site129.']
# 22384
# ['B1_site130.']
# 22694
# ['B1_site131.']
# 22926
# ['B1_site132.']
# 23197
# ['B1_site133.']
# 23321
# ['B1_site134.']
# 23507
# ['B1_site135.']
# 23601
# ['B1_site136.']
# 23732
# ['B1_site137.']
# 23852
# ['B1_site138.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_22000_24000_B1_Site-138.ch6.tif
# 24029
# ['B1_site139.']
# 24029
# ['B1_site140.']
# 24175
# ['B1_site141.']
# 24191
# ['B1_site142.']
# 24343
# ['B1_site143.']
# 24379
# ['B1_site144.']
# 24552
# ['B1_site145.']
# 24621
# ['B1_site146.']
# 24915
# ['B1_site147.']
# 25035
# ['B1_site148.']
# 25355
# ['B1_site149.']
# 25491
# ['B1_site150.']
# 25741
# ['B1_site151.']
# 25846
# ['B1_site152.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_24000_26000_B1_Site-152.ch6.tif
# 26115
# ['B1_site153.']
# 26239
# ['B1_site154.']
# 26575
# ['B1_site155.']
# 26698
# ['B1_site156.']
# 26991
# ['B1_site157.']
# 27118
# ['B1_site158.']
# 27466
# ['B1_site159.']
# 27661
# ['B1_site160.']
# 27993
# ['B1_site161.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_26000_28000_B1_Site-161.ch6.tif
# 28181
# ['B1_site162.']
# 28466
# ['B1_site163.']
# 28518
# ['B1_site164.']
# 28750
# ['B1_site165.']
# 28826
# ['B1_site166.']
# 29051
# ['B1_site167.']
# 29097
# ['B1_site168.']
# 29272
# ['B1_site169.']
# 29274
# ['B1_site170.']
# 29502
# ['B1_site171.']
# 29635
# ['B1_site172.']
# 29938
# ['B1_site173.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_28000_30000_B1_Site-173.ch6.tif
# 30073
# ['B1_site174.']
# 30283
# ['B1_site175.']
# 30443
# ['B1_site176.']
# 30713
# ['B1_site177.']
# 30827
# ['B1_site178.']
# 31122
# ['B1_site179.']
# 31347
# ['B1_site180.']
# 31658
# ['B1_site181.']
# 31883
# ['B1_site182.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_30000_32000_B1_Site-182.ch6.tif
# 32203
# ['B1_site183.']
# 32336
# ['B1_site184.']
# 32633
# ['B1_site185.']
# 32817
# ['B1_site186.']
# 33072
# ['B1_site187.']
# 33240
# ['B1_site188.']
# 33503
# ['B1_site189.']
# 33616
# ['B1_site190.']
# 33821
# ['B1_site191.']
# 33926
# ['B1_site192.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_32000_34000_B1_Site-192.ch6.tif
# 34201
# ['B1_site193.']
# 34334
# ['B1_site194.']
# 34607
# ['B1_site195.']
# 34739
# ['B1_site196.']
# 34947
# ['B1_site197.']
# 35040
# ['B1_site198.']
# 35209
# ['B1_site199.']
# 35299
# ['B1_site200.']
# 35512
# ['B1_site201.']
# 35601
# ['B1_site202.']
# 35853
# ['B1_site203.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_34000_36000_B1_Site-203.ch6.tif
# 36023
# ['B1_site204.']
# 36052
# ['B1_site205.']
# 36184
# ['B1_site206.']
# 36203
# ['B1_site207.']
# 36292
# ['B1_site208.']
# 36333
# ['B1_site209.']
# 36516
# ['B1_site210.']
# 36621
# ['B1_site211.']
# 36829
# ['B1_site212.']
# 37002
# ['B1_site213.']
# 37209
# ['B1_site214.']
# 37281
# ['B1_site215.']
# 37487
# ['B1_site216.']
# 37539
# ['B1_site217.']
# 37682
# ['B1_site218.']
# 37744
# ['B1_site219.']
# 37892
# ['B1_site220.']
# 37931
# ['B1_site221.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_36000_38000_B1_Site-221.ch6.tif
# 38198
# ['B1_site222.']
# 38290
# ['B1_site223.']
# 38496
# ['B1_site224.']
# 38622
# ['B1_site225.']
# 38838
# ['B1_site226.']
# 38962
# ['B1_site227.']
# 39204
# ['B1_site228.']
# 39273
# ['B1_site229.']
# 39479
# ['B1_site230.']
# 39525
# ['B1_site231.']
# 39680
# ['B1_site232.']
# 39710
# ['B1_site233.']
# 39883
# ['B1_site234.']
# 39883
# ['B1_site235.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_38000_40000_B1_Site-235.ch6.tif
# 40030
# ['B1_site236.']
# 40030
# ['B1_site237.']
# 40337
# ['B1_site238.']
# 40445
# ['B1_site239.']
# 40671
# ['B1_site240.']
# 40767
# ['B1_site241.']
# 40965
# ['B1_site242.']
# 41079
# ['B1_site243.']
# 41323
# ['B1_site244.']
# 41463
# ['B1_site245.']
# 41745
# ['B1_site246.']
# 41973
# ['B1_site247.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_40000_42000_B1_Site-247.ch6.tif
# 42254
# ['B1_site248.']
# 42441
# ['B1_site249.']
# 42667
# ['B1_site250.']
# 42837
# ['B1_site251.']
# 43083
# ['B1_site252.']
# 43192
# ['B1_site253.']
# 43383
# ['B1_site254.']
# 43500
# ['B1_site255.']
# 43683
# ['B1_site256.']
# 43776
# ['B1_site257.']
# 43966
# ['B1_site258.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_42000_44000_B1_Site-258.ch6.tif
# 44120
# ['B1_site259.']
# 44353
# ['B1_site260.']
# 44513
# ['B1_site261.']
# 44828
# ['B1_site262.']
# 44988
# ['B1_site263.']
# 45252
# ['B1_site264.']
# 45379
# ['B1_site265.']
# 45616
# ['B1_site266.']
# 45698
# ['B1_site267.']
# 45899
# ['B1_site268.']
# 45984
# ['B1_site269.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_44000_46000_B1_Site-269.ch6.tif
# 46173
# ['B1_site270.']
# 46253
# ['B1_site271.']
# 46290
# ['B1_site272.']
# 46465
# ['B1_site273.']
# 46504
# ['B1_site274.']
# 46647
# ['B1_site275.']
# 46722
# ['B1_site276.']
# 46914
# ['B1_site277.']
# 46985
# ['B1_site278.']
# 47233
# ['B1_site279.']
# 47339
# ['B1_site280.']
# 47594
# ['B1_site281.']
# 47692
# ['B1_site282.']
# 47890
# ['B1_site283.']
# 47944
# ['B1_site284.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_46000_48000_B1_Site-284.ch6.tif
# 48104
# ['B1_site285.']
# 48121
# ['B1_site286.']
# 48248
# ['B1_site287.']
# 48248
# ['B1_site288.']
# 48347
# ['B1_site289.']
# 48410
# ['B1_site290.']
# 48579
# ['B1_site291.']
# 48613
# ['B1_site292.']
# 48766
# ['B1_site293.']
# 48827
# ['B1_site294.']
# 49077
# ['B1_site295.']
# 49165
# ['B1_site296.']
# 49418
# ['B1_site297.']
# 49495
# ['B1_site298.']
# 49727
# ['B1_site299.']
# 49784
# ['B1_site300.']
# 49964
# ['B1_site301.']
# 49993
# ['B1_site302.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_48000_50000_B1_Site-302.ch6.tif
# 50173
# ['B1_site303.']
# 50199
# ['B1_site304.']
# 50357
# ['B1_site305.']
# 50357
# ['B1_site306.']
# 50618
# ['B1_site307.']
# 50751
# ['B1_site308.']
# 51011
# ['B1_site309.']
# 51139
# ['B1_site310.']
# 51356
# ['B1_site311.']
# 51455
# ['B1_site312.']
# 51695
# ['B1_site313.']
# 51873
# ['B1_site314.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_50000_52000_B1_Site-314.ch6.tif
# 52118
# ['B1_site315.']
# 52294
# ['B1_site316.']
# 52576
# ['B1_site317.']
# 52690
# ['B1_site318.']
# 52974
# ['B1_site319.']
# 53138
# ['B1_site320.']
# 53325
# ['B1_site321.']
# 53398
# ['B1_site322.']
# 53569
# ['B1_site323.']
# 53645
# ['B1_site324.']
# 53843
# ['B1_site325.']
# 53903
# ['B1_site326.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_52000_54000_B1_Site-326.ch6.tif
# 54103
# ['B1_site327.']
# 54180
# ['B1_site328.']
# 54378
# ['B1_site329.']
# 54523
# ['B1_site330.']
# 54793
# ['B1_site331.']
# 54941
# ['B1_site332.']
# 55294
# ['B1_site333.']
# 55497
# ['B1_site334.']
# 55859
# ['B1_site335.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_54000_56000_B1_Site-335.ch6.tif
# 56067
# ['B1_site336.']
# 56296
# ['B1_site337.']
# 56411
# ['B1_site338.']
# 56644
# ['B1_site339.']
# 56732
# ['B1_site340.']
# 56951
# ['B1_site341.']
# 57064
# ['B1_site342.']
# 57325
# ['B1_site343.']
# 57497
# ['B1_site344.']
# 57545
# ['B1_site345.']
# 57773
# ['B1_site346.']
# 57845
# ['B1_site347.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_56000_58000_B1_Site-347.ch6.tif
# 58004
# ['B1_site348.']
# 58056
# ['B1_site349.']
# 58320
# ['B1_site350.']
# 58387
# ['B1_site351.']
# 58701
# ['B1_site352.']
# 58864
# ['B1_site353.']
# 59128
# ['B1_site354.']
# 59154
# ['B1_site355.']
# 59339
# ['B1_site356.']
# 59429
# ['B1_site357.']
# 59642
# ['B1_site358.']
# 59677
# ['B1_site359.']
# 59816
# ['B1_site360.']
# 59816
# ['B1_site361.']
# 59980
# ['B1_site362.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_58000_60000_B1_Site-362.ch6.tif
# 60023
# ['B1_site363.']
# 60177
# ['B1_site364.']
# 60177
# ['B1_site365.']
# 60322
# ['B1_site366.']
# 60359
# ['B1_site367.']
# 60566
# ['B1_site368.']
# 60638
# ['B1_site369.']
# 60848
# ['B1_site370.']
# 60895
# ['B1_site371.']
# 61154
# ['B1_site372.']
# 61223
# ['B1_site373.']
# 61463
# ['B1_site374.']
# 61540
# ['B1_site375.']
# 61709
# ['B1_site376.']
# 61758
# ['B1_site377.']
# 61963
# ['B1_site378.']
# 61993
# ['B1_site379.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_60000_62000_B1_Site-379.ch6.tif
# 62202
# ['B1_site380.']
# 62220
# ['B1_site381.']
# 62471
# ['B1_site382.']
# 62598
# ['B1_site383.']
# 62807
# ['B1_site384.']
# 62930
# ['B1_site385.']
# 63126
# ['B1_site386.']
# 63208
# ['B1_site387.']
# 63453
# ['B1_site388.']
# 63582
# ['B1_site389.']
# 63798
# ['B1_site390.']
# 63881
# ['B1_site391.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_62000_64000_B1_Site-391.ch6.tif
# 64020
# ['B1_site392.']
# 64090
# ['B1_site393.']
# 64242
# ['B1_site394.']
# 64307
# ['B1_site395.']
# 64480
# ['B1_site396.']
# 64554
# ['B1_site397.']
# 64734
# ['B1_site398.']
# 64821
# ['B1_site399.']
# 64994
# ['B1_site400.']
# 65091
# ['B1_site401.']
# 65270
# ['B1_site402.']
# 65414
# ['B1_site403.']
# 65616
# ['B1_site404.']
# 65745
# ['B1_site405.']
# 65977
# ['B1_site406.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_64000_66000_B1_Site-406.ch6.tif
# 66128
# ['B1_site407.']
# 66373
# ['B1_site408.']
# 66578
# ['B1_site409.']
# 66913
# ['B1_site410.']
# 67216
# ['B1_site411.']
# 67546
# ['B1_site412.']
# 67702
# ['B1_site413.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_66000_68000_B1_Site-413.ch6.tif
# 68006
# ['B1_site414.']
# 68156
# ['B1_site415.']
# 68446
# ['B1_site416.']
# 68600
# ['B1_site417.']
# 68876
# ['B1_site418.']
# 68986
# ['B1_site419.']
# 69044
# ['B1_site420.']
# 69292
# ['B1_site421.']
# 69330
# ['B1_site422.']
# 69602
# ['B1_site423.']
# 69738
# ['B1_site424.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_68000_70000_B1_Site-424.ch6.tif
# 70049
# ['B1_site425.']
# 70244
# ['B1_site426.']
# 70565
# ['B1_site427.']
# 70734
# ['B1_site428.']
# 71023
# ['B1_site429.']
# 71172
# ['B1_site430.']
# 71394
# ['B1_site431.']
# 71464
# ['B1_site432.']
# 71704
# ['B1_site433.']
# 71768
# ['B1_site434.']
# 71960
# ['B1_site435.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_70000_72000_B1_Site-435.ch6.tif
# 72022
# ['B1_site436.']
# 72215
# ['B1_site437.']
# 72264
# ['B1_site438.']
# 72430
# ['B1_site439.']
# 72460
# ['B1_site440.']
# 72566
# ['B1_site441.']
# 72581
# ['B1_site442.']
# 72756
# ['B1_site443.']
# 72758
# ['B1_site444.']
# 72897
# ['B1_site445.']
# 72916
# ['B1_site446.']
# 73062
# ['B1_site447.']
# 73088
# ['B1_site448.']
# 73238
# ['B1_site449.']
# 73276
# ['B1_site450.']
# 73471
# ['B1_site451.']
# 73545
# ['B1_site452.']
# 73747
# ['B1_site453.']
# 73799
# ['B1_site454.']
# 73920
# ['B1_site455.']
# 73920
# ['B1_site456.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_72000_74000_B1_Site-456.ch6.tif
# 74094
# ['B1_site457.']
# 74098
# ['B1_site458.']
# 74278
# ['B1_site459.']
# 74551
# ['B1_site460.']
# 74646
# ['B1_site461.']
# 74877
# ['B1_site462.']
# 74968
# ['B1_site463.']
# 75254
# ['B1_site464.']
# 75371
# ['B1_site465.']
# 75586
# ['B1_site466.']
# 75725
# ['B1_site467.']
# 75982
# ['B1_site468.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_74000_76000_B1_Site-468.ch6.tif
# 76117
# ['B1_site469.']
# 76269
# ['B1_site470.']
# 76344
# ['B1_site471.']
# 76496
# ['B1_site472.']
# 76529
# ['B1_site473.']
# 76682
# ['B1_site474.']
# 76757
# ['B1_site475.']
# 76964
# ['B1_site476.']
# 77027
# ['B1_site477.']
# 77252
# ['B1_site478.']
# 77423
# ['B1_site479.']
# 77697
# ['B1_site480.']
# 77830
# ['B1_site481.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_76000_78000_B1_Site-481.ch6.tif
# 78049
# ['B1_site482.']
# 78194
# ['B1_site483.']
# 78481
# ['B1_site484.']
# 78611
# ['B1_site485.']
# 78879
# ['B1_site486.']
# 79047
# ['B1_site487.']
# 79346
# ['B1_site488.']
# 79558
# ['B1_site489.']
# 79879
# ['B1_site490.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_78000_80000_B1_Site-490.ch6.tif
# 80135
# ['B1_site491.']
# 80436
# ['B1_site492.']
# 80645
# ['B1_site493.']
# 80927
# ['B1_site494.']
# 81110
# ['B1_site495.']
# 81397
# ['B1_site496.']
# 81578
# ['B1_site497.']
# 81806
# ['B1_site498.']
# 81863
# ['B1_site499.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_80000_82000_B1_Site-499.ch6.tif
# 82125
# ['B1_site500.']
# 82242
# ['B1_site501.']
# 82559
# ['B1_site502.']
# 82707
# ['B1_site503.']
# 83109
# ['B1_site504.']
# 83273
# ['B1_site505.']
# 83604
# ['B1_site506.']
# 83768
# ['B1_site507.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_82000_84000_B1_Site-507.ch6.tif
# 84052
# ['B1_site508.']
# 84113
# ['B1_site509.']
# 84375
# ['B1_site510.']
# 84469
# ['B1_site511.']
# 84688
# ['B1_site512.']
# 84767
# ['B1_site513.']
# 85121
# ['B1_site514.']
# 85159
# ['B1_site515.']
# 85377
# ['B1_site516.']
# 85408
# ['B1_site517.']
# 85626
# ['B1_site518.']
# 85645
# ['B1_site519.']
# 85778
# ['B1_site520.']
# 85778
# ['B1_site521.']
# 85896
# ['B1_site522.']
# 85935
# ['B1_site523.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_84000_86000_B1_Site-523.ch6.tif
# 86052
# ['B1_site524.']
# 86052
# ['B1_site525.']
# 86180
# ['B1_site526.']
# 86210
# ['B1_site527.']
# 86318
# ['B1_site528.']
# 86354
# ['B1_site529.']
# 86564
# ['B1_site530.']
# 86654
# ['B1_site531.']
# 86837
# ['B1_site532.']
# 86861
# ['B1_site533.']
# 87026
# ['B1_site534.']
# 87057
# ['B1_site535.']
# 87188
# ['B1_site536.']
# 87229
# ['B1_site537.']
# 87497
# ['B1_site538.']
# 87792
# ['B1_site539.']
# 87865
# ['B1_site540.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_86000_88000_B1_Site-540.ch6.tif
# 88096
# ['B1_site541.']
# 88184
# ['B1_site542.']
# 88423
# ['B1_site543.']
# 88527
# ['B1_site544.']
# 88610
# ['B1_site545.']
# 88775
# ['B1_site546.']
# 89004
# ['B1_site547.']
# 89073
# ['B1_site548.']
# 89194
# ['B1_site549.']
# 89322
# ['B1_site550.']
# 89482
# ['B1_site551.']
# 89544
# ['B1_site552.']
# 89708
# ['B1_site553.']
# 89808
# ['B1_site554.']
# 89973
# ['B1_site555.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_88000_90000_B1_Site-555.ch6.tif
# 90100
# ['B1_site556.']
# 90245
# ['B1_site557.']
# 90334
# ['B1_site558.']
# 90541
# ['B1_site559.']
# 90649
# ['B1_site560.']
# 90868
# ['B1_site561.']
# 91076
# ['B1_site562.']
# 91387
# ['B1_site563.']
# 91591
# ['B1_site564.']
# 91884
# ['B1_site565.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_90000_92000_B1_Site-565.ch6.tif
# 92052
# ['B1_site566.']
# 92323
# ['B1_site567.']
# 92500
# ['B1_site568.']
# 92826
# ['B1_site569.']
# 93018
# ['B1_site570.']
# 93350
# ['B1_site571.']
# 93572
# ['B1_site572.']
# 93974
# ['B1_site573.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_92000_94000_B1_Site-573.ch6.tif
# 94231
# ['B1_site574.']
# 94560
# ['B1_site575.']
# 94714
# ['B1_site576.']
# 94978
# ['B1_site577.']
# 95123
# ['B1_site578.']
# 95326
# ['B1_site579.']
# 95491
# ['B1_site580.']
# 95536
# ['B1_site581.']
# 95777
# ['B1_site582.']
# 95954
# ['B1_site583.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_94000_96000_B1_Site-583.ch6.tif
# 96090
# ['B1_site584.']
# 96245
# ['B1_site585.']
# 96665
# ['B1_site586.']
# 96831
# ['B1_site587.']
# 97203
# ['B1_site588.']
# 97351
# ['B1_site589.']
# 97627
# ['B1_site590.']
# 97714
# ['B1_site591.']
# 97907
# ['B1_site592.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_96000_98000_B1_Site-592.ch6.tif
# 98028
# ['B1_site593.']
# 98252
# ['B1_site594.']
# 98380
# ['B1_site595.']
# 98650
# ['B1_site596.']
# 98796
# ['B1_site597.']
# 99063
# ['B1_site598.']
# 99084
# ['B1_site599.']
# 99241
# ['B1_site600.']
# 99264
# ['B1_site601.']
# 99407
# ['B1_site602.']
# 99423
# ['B1_site603.']
# 99518
# ['B1_site604.']
# 99543
# ['B1_site605.']
# 99642
# ['B1_site606.']
# 99650
# ['B1_site607.']
# 99748
# ['B1_site608.']
# 99783
# ['B1_site609.']
# 99959
# ['B1_site610.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_98000_100000_B1_Site-610.ch6.tif
# 100038
# ['B1_site611.']
# 100227
# ['B1_site612.']
# 100306
# ['B1_site613.']
# 100529
# ['B1_site614.']
# 100547
# ['B1_site615.']
# 100723
# ['B1_site616.']
# 100723
# ['B1_site617.']
# 100901
# ['B1_site618.']
# 100901
# ['B1_site619.']
# 101148
# ['B1_site620.']
# 101479
# ['B1_site621.']
# 101552
# ['B1_site622.']
# 101812
# ['B1_site623.']
# 101934
# ['B1_site624.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_100000_102000_B1_Site-624.ch6.tif
# 102202
# ['B1_site625.']
# 102333
# ['B1_site626.']
# 102560
# ['B1_site627.']
# 102709
# ['B1_site628.']
# 102932
# ['B1_site629.']
# 103037
# ['B1_site630.']
# 103166
# ['B1_site631.']
# 103294
# ['B1_site632.']
# 103444
# ['B1_site633.']
# 103525
# ['B1_site634.']
# 103647
# ['B1_site635.']
# 103705
# ['B1_site636.']
# 103866
# ['B1_site637.']
# 103920
# ['B1_site638.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_102000_104000_B1_Site-638.ch6.tif
# 104063
# ['B1_site639.']
# 104125
# ['B1_site640.']
# 104273
# ['B1_site641.']
# 104408
# ['B1_site642.']
# 104676
# ['B1_site643.']
# 104834
# ['B1_site644.']
# 105099
# ['B1_site645.']
# 105238
# ['B1_site646.']
# 105505
# ['B1_site647.']
# 105681
# ['B1_site648.']
# 105931
# ['B1_site649.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_104000_106000_B1_Site-649.ch6.tif
# 106039
# ['B1_site650.']
# 106285
# ['B1_site651.']
# 106463
# ['B1_site652.']
# 106756
# ['B1_site653.']
# 106973
# ['B1_site654.']
# 107323
# ['B1_site655.']
# 107621
# ['B1_site656.']
# 107957
# ['B1_site657.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_106000_108000_B1_Site-657.ch6.tif
# 108086
# ['B1_site658.']
# 108360
# ['B1_site659.']
# 108490
# ['B1_site660.']
# 108771
# ['B1_site661.']
# ...
# 166874
# ['B1_site1046.']
# 166920
# ['B1_site1047.']
# 167143
# ['B1_site1048.']
# 167184
# ['B1_site1049.']
# 167328
# ['B1_site1050.']
# 167346
# ['B1_site1051.']
# 167463
# ['B1_site1052.']
# 167527
# ['B1_site1053.']
# 167729
# ['B1_site1054.']
# 167773
# ['B1_site1055.']
# 167951
# ['B1_site1056.']
# 167951
# ['B1_site1057.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B1_Site-1057.ch6.tif
# 168159
# ['B1_site1058.']
# 168227
# ['B1_site1059.']
# 168396
# ['B1_site1060.']
# 168494
# ['B1_site1061.']
# 168725
# ['B1_site1062.']
# 168789
# ['B1_site1063.']
# 169000
# ['B1_site1064.']
# 169000
# ['B1_site1065.']
# 169247
# ['B1_site1066.']
# 169309
# ['B1_site1067.']
# 169508
# ['B1_site1068.']
# 169600
# ['B1_site1069.']
# 169818
# ['B1_site1070.']
# 169869
# ['B1_site1071.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_168000_170000_B1_Site-1071.ch6.tif
# 170044
# ['B1_site1072.']
# 170094
# ['B1_site1073.']
# 170250
# ['B1_site1074.']
# 170286
# ['B1_site1075.']
# 170470
# ['B1_site1076.']
# 170511
# ['B1_site1077.']
# 170699
# ['B1_site1078.']
# 170944
# ['B1_site1079.']
# 171060
# ['B1_site1080.']
# 171315
# ['B1_site1081.']
# 171431
# ['B1_site1082.']
# 171673
# ['B1_site1083.']
# 171799
# ['B1_site1084.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_170000_172000_B1_Site-1084.ch6.tif
# 172001
# ['B1_site1085.']
# 172133
# ['B1_site1086.']
# 172400
# ['B1_site1087.']
# 172568
# ['B1_site1088.']
# 172800
# ['B1_site1089.']
# 172949
# ['B1_site1090.']
# 173168
# ['B1_site1091.']
# 173284
# ['B1_site1092.']
# 173502
# ['B1_site1093.']
# 173615
# ['B1_site1094.']
# 173886
# ['B1_site1095.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_172000_174000_B1_Site-1095.ch6.tif
# 174022
# ['B1_site1096.']
# 174244
# ['B1_site1097.']
# 174374
# ['B1_site1098.']
# 174608
# ['B1_site1099.']
# 174713
# ['B1_site1100.']
# 174966
# ['B1_site1101.']
# 175089
# ['B1_site1102.']
# 175253
# ['B1_site1103.']
# 175315
# ['B1_site1104.']
# 175488
# ['B1_site1105.']
# 175555
# ['B1_site1106.']
# 175757
# ['B1_site1107.']
# 175868
# ['B1_site1108.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_174000_176000_B1_Site-1108.ch6.tif
# 176143
# ['B1_site1109.']
# 176366
# ['B1_site1110.']
# 176760
# ['B1_site1111.']
# 176961
# ['B1_site1112.']
# 177258
# ['B1_site1113.']
# 177350
# ['B1_site1114.']
# 177575
# ['B1_site1115.']
# 177643
# ['B1_site1116.']
# 177732
# ['B1_site1117.']
# 177782
# ['B1_site1118.']
# 177949
# ['B1_site1119.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_176000_178000_B1_Site-1119.ch6.tif
# 178001
# ['B1_site1120.']
# 178220
# ['B1_site1121.']
# 178279
# ['B1_site1122.']
# 178476
# ['B1_site1123.']
# 178560
# ['B1_site1124.']
# 178800
# ['B1_site1125.']
# 178858
# ['B1_site1126.']
# 179073
# ['B1_site1127.']
# 179131
# ['B1_site1128.']
# 179368
# ['B1_site1129.']
# 179446
# ['B1_site1130.']
# 179658
# ['B1_site1131.']
# 179726
# ['B1_site1132.']
# 179937
# ['B1_site1133.']
# 179995
# ['B1_site1134.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_178000_180000_B1_Site-1134.ch6.tif
# 180208
# ['B1_site1135.']
# 180256
# ['B1_site1136.']
# 180459
# ['B1_site1137.']
# 180522
# ['B1_site1138.']
# 180698
# ['B1_site1139.']
# 180743
# ['B1_site1140.']
# 180920
# ['B1_site1141.']
# 180920
# ['B1_site1142.']
# 181168
# ['B1_site1143.']
# 181264
# ['B1_site1144.']
# 181489
# ['B1_site1145.']
# 181578
# ['B1_site1146.']
# 181746
# ['B1_site1147.']
# 181831
# ['B1_site1148.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_180000_182000_B1_Site-1148.ch6.tif
# 182056
# ['B1_site1149.']
# 182149
# ['B1_site1150.']
# 182417
# ['B1_site1151.']
# 182526
# ['B1_site1152.']
# 182829
# ['B1_site1153.']
# 182958
# ['B1_site1154.']
# 183232
# ['B1_site1155.']
# 183302
# ['B1_site1156.']
# 183564
# ['B1_site1157.']
# 183724
# ['B1_site1158.']
# 183938
# ['B1_site1159.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_182000_184000_B1_Site-1159.ch6.tif
# 184040
# ['B1_site1160.']
# 184345
# ['B1_site1161.']
# 184465
# ['B1_site1162.']
# 184705
# ['B1_site1163.']
# 184770
# ['B1_site1164.']
# 185038
# ['B1_site1165.']
# 185130
# ['B1_site1166.']
# 185353
# ['B1_site1167.']
# 185477
# ['B1_site1168.']
# 185802
# ['B1_site1169.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_184000_186000_B1_Site-1169.ch6.tif
# 186004
# ['B1_site1170.']
# 186366
# ['B1_site1171.']
# 186473
# ['B1_site1172.']
# 186729
# ['B1_site1173.']
# 186754
# ['B1_site1174.']
# 186886
# ['B1_site1175.']
# 186902
# ['B1_site1176.']
# 187038
# ['B1_site1177.']
# 187083
# ['B1_site1178.']
# 187296
# ['B1_site1179.']
# 187357
# ['B1_site1180.']
# 187530
# ['B1_site1181.']
# 187585
# ['B1_site1182.']
# 187778
# ['B1_site1183.']
# 187828
# ['B1_site1184.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_186000_188000_B1_Site-1184.ch6.tif
# 188075
# ['B1_site1185.']
# 188101
# ['B1_site1186.']
# 188286
# ['B1_site1187.']
# 188286
# ['B1_site1188.']
# 188486
# ['B1_site1189.']
# 188518
# ['B1_site1190.']
# 188694
# ['B1_site1191.']
# 188734
# ['B1_site1192.']
# 188896
# ['B1_site1193.']
# 188920
# ['B1_site1194.']
# 189113
# ['B1_site1195.']
# 189113
# ['B1_site1196.']
# 189333
# ['B1_site1197.']
# 189333
# ['B1_site1198.']
# 189565
# ['B1_site1199.']
# 189656
# ['B1_site1200.']
# 189872
# ['B1_site1201.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_188000_190000_B1_Site-1201.ch6.tif
# 190031
# ['B1_site1202.']
# 190288
# ['B1_site1203.']
# 190400
# ['B1_site1204.']
# 190629
# ['B1_site1205.']
# 190749
# ['B1_site1206.']
# 190963
# ['B1_site1207.']
# 191047
# ['B1_site1208.']
# 191251
# ['B1_site1209.']
# 191357
# ['B1_site1210.']
# 191576
# ['B1_site1211.']
# 191671
# ['B1_site1212.']
# 191859
# ['B1_site1213.']
# 191920
# ['B1_site1214.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_190000_192000_B1_Site-1214.ch6.tif
# 192161
# ['B1_site1215.']
# 192253
# ['B1_site1216.']
# 192488
# ['B1_site1217.']
# 192588
# ['B1_site1218.']
# 192758
# ['B1_site1219.']
# 192808
# ['B1_site1220.']
# 193005
# ['B1_site1221.']
# 193145
# ['B1_site1222.']
# 193469
# ['B1_site1223.']
# 193545
# ['B1_site1224.']
# 193576
# ['B1_site1225.']
# 193635
# ['B1_site1226.']
# 193692
# ['B1_site1227.']
# 193838
# ['B1_site1228.']
# 193867
# ['B1_site1229.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_192000_194000_B1_Site-1229.ch6.tif
# 194084
# ['B1_site1230.']
# 194112
# ['B1_site1231.']
# 194294
# ['B1_site1232.']
# 194337
# ['B1_site1233.']
# 194446
# ['B1_site1234.']
# 194446
# ['B1_site1235.']
# 194611
# ['B1_site1236.']
# 194646
# ['B1_site1237.']
# 194825
# ['B1_site1238.']
# 194825
# ['B1_site1239.']
# 194985
# ['B1_site1240.']
# 195036
# ['B1_site1241.']
# 195222
# ['B1_site1242.']
# 195247
# ['B1_site1243.']
# 195340
# ['B1_site1244.']
# 195610
# ['B1_site1245.']
# 195714
# ['B1_site1246.']
# 195970
# ['B1_site1247.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_194000_196000_B1_Site-1247.ch6.tif
# 196080
# ['B1_site1248.']
# 196324
# ['B1_site1249.']
# 196407
# ['B1_site1250.']
# 196580
# ['B1_site1251.']
# 196657
# ['B1_site1252.']
# 196873
# ['B1_site1253.']
# 196960
# ['B1_site1254.']
# 197205
# ['B1_site1255.']
# 197315
# ['B1_site1256.']
# 197574
# ['B1_site1257.']
# 197675
# ['B1_site1258.']
# 197933
# ['B1_site1259.']
# saving
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch0.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch1.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch2.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch3.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch4.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch5.tif
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_196000_198000_B1_Site-1259.ch6.tif
# 198010
# ['B1_site1260.']
# 198224
# ['B1_site1261.']
# 198224
# ['B1_site1262.']
# 198224
# ['B1_site1263.']
# 198407
# ['B1_site1264.']
# 198407
# ['B1_site1265.']
# 198477
# ['B1_site1266.']
# 198477
# ['B1_site1267.']
# 198622
# ['B1_site1268.']
# 198622
# ['B1_site1269.']
# 198713
# ['B1_site1270.']
# 198746
# ['B1_site1271.']
# 198915
# ['B1_site1272.']
# 198966
# ['B1_site1273.']
# 199083
# ['B1_site1274.']
# 199223
# ['B1_site1275.']
# 199446
# ['B1_site1276.']
# 199528
# ['B1_site1277.']
# 199622
# ['B1_site1278.']
# 199622
# ['B1_site1279.']
# 199876
# ['B1_site1280.']
# saving last site and cell
# (1968, 7, 299, 299)

# %%
plate = "M40A"
well = "A3"
site = 1256
cell = 935
ix = df_26.query('well == @well & plate == @plate & site == @site & cell == @cell').index[0]
ofint = df_26.copy().iloc[ix+1:,:].query('well == @well & plate == @plate')
save_singlecells_finish(
                 plate = plate, well = well, start = 144000,
                 nchannels = 7, 
                df_cells_interest = ofint)


####
# Out:
# # sites
# 1281
# 144000
# ['A3_site0.']
# 144000
# ['A3_site1.']
# 144000
# ['A3_site2.']
# 144000
# ['A3_site3.']
# 144000
# ['A3_site4.']
# 144000
# ['A3_site5.']
# 144000
# ['A3_site6.']
# 144000
# ['A3_site7.']
# 144000
# ['A3_site8.']
# 144000
# ['A3_site9.']
# 144000
# ['A3_site10.']
# 144000
# ['A3_site11.']
# 144000
# ['A3_site12.']
# 144000
# ['A3_site13.']
# 144000
# ['A3_site14.']
# 144000
# ['A3_site15.']
# 144000
# ['A3_site16.']
# 144000
# ['A3_site17.']
# 144000
# ['A3_site18.']
# 144000
# ['A3_site19.']
# 144000
# ['A3_site20.']
# 144000
# ['A3_site21.']
# 144000
# ['A3_site22.']
# 144000
# ['A3_site23.']
# 144000
# ['A3_site24.']
# 144000
# ['A3_site25.']
# 144000
# ['A3_site26.']
# 144000
# ['A3_site27.']
# 144000
# ['A3_site28.']
# 144000
# ['A3_site29.']
# 144000
# ['A3_site30.']
# 144000
# ['A3_site31.']
# 144000
# ['A3_site32.']
# 144000
# ['A3_site33.']
# 144000
# ['A3_site34.']
# 144000
# ['A3_site35.']
# 144000
# ['A3_site36.']
# 144000
# ['A3_site37.']
# 144000
# ['A3_site38.']
# 144000
# ['A3_site39.']
# 144000
# ['A3_site40.']
# 144000
# ['A3_site41.']
# 144000
# ['A3_site42.']
# 144000
# ['A3_site43.']
# 144000
# ['A3_site44.']
# 144000
# ['A3_site45.']
# 144000
# ['A3_site46.']
# 144000
# ['A3_site47.']
# 144000
# ['A3_site48.']
# 144000
# ['A3_site49.']
# 144000
# ['A3_site50.']
# 144000
# ['A3_site51.']
# 144000
# ['A3_site52.']
# 144000
# ['A3_site53.']
# 144000
# ['A3_site54.']
# 144000
# ['A3_site55.']
# 144000
# ['A3_site56.']
# 144000
# ['A3_site57.']
# 144000
# ['A3_site58.']
# 144000
# ['A3_site59.']
# 144000
# ['A3_site60.']
# 144000
# ['A3_site61.']
# 144000
# ['A3_site62.']
# 144000
# ['A3_site63.']
# 144000
# ['A3_site64.']
# 144000
# ['A3_site65.']
# 144000
# ['A3_site66.']
# 144000
# ['A3_site67.']
# 144000
# ['A3_site68.']
# 144000
# ['A3_site69.']
# 144000
# ['A3_site70.']
# 144000
# ['A3_site71.']
# 144000
# ['A3_site72.']
# 144000
# ['A3_site73.']
# 144000
# ['A3_site74.']
# 144000
# ['A3_site75.']
# 144000
# ['A3_site76.']
# 144000
# ['A3_site77.']
# 144000
# ['A3_site78.']
# 144000
# ['A3_site79.']
# 144000
# ['A3_site80.']
# 144000
# ['A3_site81.']
# 144000
# ['A3_site82.']
# 144000
# ['A3_site83.']
# 144000
# ['A3_site84.']
# 144000
# ['A3_site85.']
# 144000
# ['A3_site86.']
# 144000
# ['A3_site87.']
# 144000
# ['A3_site88.']
# 144000
# ['A3_site89.']
# 144000
# ['A3_site90.']
# 144000
# ['A3_site91.']
# 144000
# ['A3_site92.']
# 144000
# ['A3_site93.']
# 144000
# ['A3_site94.']
# 144000
# ['A3_site95.']
# 144000
# ['A3_site96.']
# 144000
# ['A3_site97.']
# 144000
# ['A3_site98.']
# 144000
# ['A3_site99.']
# 144000
# ['A3_site100.']
# 144000
# ['A3_site101.']
# 144000
# ['A3_site102.']
# 144000
# ['A3_site103.']
# 144000
# ['A3_site104.']
# 144000
# ['A3_site105.']
# 144000
# ['A3_site106.']
# 144000
# ['A3_site107.']
# 144000
# ['A3_site108.']
# 144000
# ['A3_site109.']
# 144000
# ['A3_site110.']
# 144000
# ['A3_site111.']
# 144000
# ['A3_site112.']
# 144000
# ['A3_site113.']
# 144000
# ['A3_site114.']
# 144000
# ['A3_site115.']
# 144000
# ['A3_site116.']
# 144000
# ['A3_site117.']
# 144000
# ['A3_site118.']
# 144000
# ['A3_site119.']
# 144000
# ['A3_site120.']
# 144000
# ['A3_site121.']
# 144000
# ['A3_site122.']
# 144000
# ['A3_site123.']
# 144000
# ['A3_site124.']
# 144000
# ['A3_site125.']
# 144000
# ['A3_site126.']
# 144000
# ['A3_site127.']
# 144000
# ['A3_site128.']
# 144000
# ['A3_site129.']
# 144000
# ['A3_site130.']
# 144000
# ['A3_site131.']
# 144000
# ['A3_site132.']
# 144000
# ['A3_site133.']
# 144000
# ['A3_site134.']
# 144000
# ['A3_site135.']
# 144000
# ['A3_site136.']
# 144000
# ['A3_site137.']
# 144000
# ['A3_site138.']
# 144000
# ['A3_site139.']
# 144000
# ['A3_site140.']
# 144000
# ['A3_site141.']
# 144000
# ['A3_site142.']
# 144000
# ['A3_site143.']
# 144000
# ['A3_site144.']
# 144000
# ['A3_site145.']
# 144000
# ['A3_site146.']
# 144000
# ['A3_site147.']
# 144000
# ['A3_site148.']
# 144000
# ['A3_site149.']
# 144000
# ['A3_site150.']
# 144000
# ['A3_site151.']
# 144000
# ['A3_site152.']
# 144000
# ['A3_site153.']
# 144000
# ['A3_site154.']
# 144000
# ['A3_site155.']
# 144000
# ['A3_site156.']
# 144000
# ['A3_site157.']
# 144000
# ['A3_site158.']
# 144000
# ['A3_site159.']
# 144000
# ['A3_site160.']
# 144000
# ['A3_site161.']
# 144000
# ['A3_site162.']
# 144000
# ['A3_site163.']
# 144000
# ['A3_site164.']
# 144000
# ['A3_site165.']
# 144000
# ['A3_site166.']
# 144000
# ['A3_site167.']
# 144000
# ['A3_site168.']
# 144000
# ['A3_site169.']
# 144000
# ['A3_site170.']
# 144000
# ['A3_site171.']
# 144000
# ['A3_site172.']
# 144000
# ['A3_site173.']
# 144000
# ['A3_site174.']
# 144000
# ['A3_site175.']
# 144000
# ['A3_site176.']
# 144000
# ['A3_site177.']
# 144000
# ['A3_site178.']
# 144000
# ['A3_site179.']
# 144000
# ['A3_site180.']
# 144000
# ['A3_site181.']
# 144000
# ['A3_site182.']
# 144000
# ['A3_site183.']
# 144000
# ['A3_site184.']
# 144000
# ['A3_site185.']
# 144000
# ['A3_site186.']
# 144000
# ['A3_site187.']
# 144000
# ['A3_site188.']
# 144000
# ['A3_site189.']
# 144000
# ['A3_site190.']
# 144000
# ['A3_site191.']
# 144000
# ['A3_site192.']
# 144000
# ['A3_site193.']
# 144000
# ['A3_site194.']
# 144000
# ['A3_site195.']
# 144000
# ['A3_site196.']
# 144000
# ['A3_site197.']
# 144000
# ['A3_site198.']
# 144000
# ['A3_site199.']
# 144000
# ['A3_site200.']
# 144000
# ['A3_site201.']
# 144000
# ['A3_site202.']
# 144000
# ['A3_site203.']
# 144000
# ['A3_site204.']
# 144000
# ['A3_site205.']
# 144000
# ['A3_site206.']
# 144000
# ['A3_site207.']
# 144000
# ['A3_site208.']
# 144000
# ['A3_site209.']
# 144000
# ['A3_site210.']
# 144000
# ['A3_site211.']
# 144000
# ['A3_site212.']
# 144000
# ['A3_site213.']
# 144000
# ['A3_site214.']
# 144000
# ['A3_site215.']
# 144000
# ['A3_site216.']
# 144000
# ['A3_site217.']
# 144000
# ['A3_site218.']
# 144000
# ['A3_site219.']
# 144000
# ['A3_site220.']
# 144000
# ['A3_site221.']
# 144000
# ['A3_site222.']
# 144000
# ['A3_site223.']
# 144000
# ['A3_site224.']
# 144000
# ['A3_site225.']
# 144000
# ['A3_site226.']
# 144000
# ['A3_site227.']
# 144000
# ['A3_site228.']
# 144000
# ['A3_site229.']
# 144000
# ['A3_site230.']
# 144000
# ['A3_site231.']
# 144000
# ['A3_site232.']
# 144000
# ['A3_site233.']
# 144000
# ['A3_site234.']
# 144000
# ['A3_site235.']
# 144000
# ['A3_site236.']
# 144000
# ['A3_site237.']
# 144000
# ['A3_site238.']
# 144000
# ['A3_site239.']
# 144000
# ['A3_site240.']
# 144000
# ['A3_site241.']
# 144000
# ['A3_site242.']
# 144000
# ['A3_site243.']
# 144000
# ['A3_site244.']
# 144000
# ['A3_site245.']
# 144000
# ['A3_site246.']
# 144000
# ['A3_site247.']
# 144000
# ['A3_site248.']
# 144000
# ['A3_site249.']
# 144000
# ['A3_site250.']
# 144000
# ['A3_site251.']
# 144000
# ['A3_site252.']
# 144000
# ['A3_site253.']
# 144000
# ['A3_site254.']
# 144000
# ['A3_site255.']
# 144000
# ['A3_site256.']
# 144000
# ['A3_site257.']
# 144000
# ['A3_site258.']
# 144000
# ['A3_site259.']
# 144000
# ['A3_site260.']
# 144000
# ['A3_site261.']
# 144000
# ['A3_site262.']
# 144000
# ['A3_site263.']
# 144000
# ['A3_site264.']
# 144000
# ['A3_site265.']
# 144000
# ['A3_site266.']
# 144000
# ['A3_site267.']
# 144000
# ['A3_site268.']
# 144000
# ['A3_site269.']
# 144000
# ['A3_site270.']
# 144000
# ['A3_site271.']
# 144000
# ['A3_site272.']
# 144000
# ['A3_site273.']
# 144000
# ['A3_site274.']
# 144000
# ['A3_site275.']
# 144000
# ['A3_site276.']
# 144000
# ['A3_site277.']
# 144000
# ['A3_site278.']
# 144000
# ['A3_site279.']
# 144000
# ['A3_site280.']
# 144000
# ['A3_site281.']
# 144000
# ['A3_site282.']
# 144000
# ['A3_site283.']
# 144000
# ['A3_site284.']
# 144000
# ['A3_site285.']
# 144000
# ['A3_site286.']
# 144000
# ['A3_site287.']
# 144000
# ['A3_site288.']
# 144000
# ['A3_site289.']
# 144000
# ['A3_site290.']
# 144000
# ['A3_site291.']
# 144000
# ['A3_site292.']
# 144000
# ['A3_site293.']
# 144000
# ['A3_site294.']
# 144000
# ['A3_site295.']
# 144000
# ['A3_site296.']
# 144000
# ['A3_site297.']
# 144000
# ['A3_site298.']
# 144000
# ['A3_site299.']
# 144000
# ['A3_site300.']
# 144000
# ['A3_site301.']
# 144000
# ['A3_site302.']
# 144000
# ['A3_site303.']
# 144000
# ['A3_site304.']
# 144000
# ['A3_site305.']
# 144000
# ['A3_site306.']
# 144000
# ['A3_site307.']
# 144000
# ['A3_site308.']
# 144000
# ['A3_site309.']
# 144000
# ['A3_site310.']
# 144000
# ['A3_site311.']
# 144000
# ['A3_site312.']
# 144000
# ['A3_site313.']
# 144000
# ['A3_site314.']
# 144000
# ['A3_site315.']
# 144000
# ['A3_site316.']
# 144000
# ['A3_site317.']
# 144000
# ['A3_site318.']
# 144000
# ['A3_site319.']
# 144000
# ['A3_site320.']
# 144000
# ['A3_site321.']
# 144000
# ['A3_site322.']
# 144000
# ['A3_site323.']
# 144000
# ['A3_site324.']
# 144000
# ['A3_site325.']
# 144000
# ['A3_site326.']
# 144000
# ['A3_site327.']
# 144000
# ['A3_site328.']
# 144000
# ['A3_site329.']
# 144000
# ['A3_site330.']
# 144000
# ['A3_site331.']
# 144000
# ['A3_site332.']
# 144000
# ['A3_site333.']
# 144000
# ['A3_site334.']
# 144000
# ['A3_site335.']
# 144000
# ['A3_site336.']
# 144000
# ['A3_site337.']
# 144000
# ['A3_site338.']
# 144000
# ['A3_site339.']
# 144000
# ['A3_site340.']
# 144000
# ['A3_site341.']
# 144000
# ['A3_site342.']
# 144000
# ['A3_site343.']
# 144000
# ['A3_site344.']
# 144000
# ['A3_site345.']
# 144000
# ['A3_site346.']
# 144000
# ['A3_site347.']
# 144000
# ['A3_site348.']
# 144000
# ['A3_site349.']
# 144000
# ['A3_site350.']
# 144000
# ['A3_site351.']
# 144000
# ['A3_site352.']
# 144000
# ['A3_site353.']
# 144000
# ['A3_site354.']
# 144000
# ['A3_site355.']
# 144000
# ['A3_site356.']
# 144000
# ['A3_site357.']
# 144000
# ['A3_site358.']
# 144000
# ['A3_site359.']
# 144000
# ['A3_site360.']
# 144000
# ['A3_site361.']
# 144000
# ['A3_site362.']
# 144000
# ['A3_site363.']
# 144000
# ['A3_site364.']
# 144000
# ['A3_site365.']
# 144000
# ['A3_site366.']
# 144000
# ['A3_site367.']
# 144000
# ['A3_site368.']
# 144000
# ['A3_site369.']
# 144000
# ['A3_site370.']
# 144000
# ['A3_site371.']
# 144000
# ['A3_site372.']
# 144000
# ['A3_site373.']
# 144000
# ['A3_site374.']
# 144000
# ['A3_site375.']
# 144000
# ['A3_site376.']
# 144000
# ['A3_site377.']
# 144000
# ['A3_site378.']
# 144000
# ['A3_site379.']
# 144000
# ['A3_site380.']
# 144000
# ['A3_site381.']
# 144000
# ['A3_site382.']
# 144000
# ['A3_site383.']
# 144000
# ['A3_site384.']
# 144000
# ['A3_site385.']
# 144000
# ['A3_site386.']
# 144000
# ['A3_site387.']
# 144000
# ['A3_site388.']
# 144000
# ['A3_site389.']
# 144000
# ['A3_site390.']
# 144000
# ['A3_site391.']
# 144000
# ['A3_site392.']
# 144000
# ['A3_site393.']
# 144000
# ['A3_site394.']
# 144000
# ['A3_site395.']
# 144000
# ['A3_site396.']
# 144000
# ['A3_site397.']
# 144000
# ['A3_site398.']
# 144000
# ['A3_site399.']
# 144000
# ['A3_site400.']
# 144000
# ['A3_site401.']
# 144000
# ['A3_site402.']
# 144000
# ['A3_site403.']
# 144000
# ['A3_site404.']
# 144000
# ['A3_site405.']
# 144000
# ['A3_site406.']
# 144000
# ['A3_site407.']
# 144000
# ['A3_site408.']
# 144000
# ['A3_site409.']
# 144000
# ['A3_site410.']
# 144000
# ['A3_site411.']
# 144000
# ['A3_site412.']
# 144000
# ['A3_site413.']
# 144000
# ['A3_site414.']
# 144000
# ['A3_site415.']
# 144000
# ['A3_site416.']
# 144000
# ['A3_site417.']
# 144000
# ['A3_site418.']
# 144000
# ['A3_site419.']
# 144000
# ['A3_site420.']
# 144000
# ['A3_site421.']
# 144000
# ['A3_site422.']
# 144000
# ['A3_site423.']
# 144000
# ['A3_site424.']
# 144000
# ['A3_site425.']
# 144000
# ['A3_site426.']
# 144000
# ['A3_site427.']
# 144000
# ['A3_site428.']
# 144000
# ['A3_site429.']
# 144000
# ['A3_site430.']
# 144000
# ['A3_site431.']
# 144000
# ['A3_site432.']
# 144000
# ['A3_site433.']
# 144000
# ['A3_site434.']
# 144000
# ['A3_site435.']
# 144000
# ['A3_site436.']
# 144000
# ['A3_site437.']
# 144000
# ['A3_site438.']
# 144000
# ['A3_site439.']
# 144000
# ['A3_site440.']
# 144000
# ['A3_site441.']
# 144000
# ['A3_site442.']
# 144000
# ['A3_site443.']
# 144000
# ['A3_site444.']
# 144000
# ['A3_site445.']
# 144000
# ['A3_site446.']
# 144000
# ['A3_site447.']
# 144000
# ['A3_site448.']
# 144000
# ['A3_site449.']
# 144000
# ['A3_site450.']
# 144000
# ['A3_site451.']
# 144000
# ['A3_site452.']
# 144000
# ['A3_site453.']
# 144000
# ['A3_site454.']
# 144000
# ['A3_site455.']
# 144000
# ['A3_site456.']
# 144000
# ['A3_site457.']
# 144000
# ['A3_site458.']
# 144000
# ['A3_site459.']
# 144000
# ['A3_site460.']
# 144000
# ['A3_site461.']
# 144000
# ['A3_site462.']
# 144000
# ['A3_site463.']
# 144000
# ['A3_site464.']
# 144000
# ['A3_site465.']
# 144000
# ['A3_site466.']
# 144000
# ['A3_site467.']
# 144000
# ['A3_site468.']
# 144000
# ['A3_site469.']
# 144000
# ['A3_site470.']
# 144000
# ['A3_site471.']
# 144000
# ['A3_site472.']
# 144000
# ['A3_site473.']
# 144000
# ['A3_site474.']
# 144000
# ['A3_site475.']
# 144000
# ['A3_site476.']
# 144000
# ['A3_site477.']
# 144000
# ['A3_site478.']
# 144000
# ['A3_site479.']
# 144000
# ['A3_site480.']
# 144000
# ['A3_site481.']
# 144000
# ['A3_site482.']
# 144000
# ['A3_site483.']
# 144000
# ['A3_site484.']
# 144000
# ['A3_site485.']
# 144000
# ['A3_site486.']
# 144000
# ['A3_site487.']
# 144000
# ['A3_site488.']
# 144000
# ['A3_site489.']
# 144000
# ['A3_site490.']
# 144000
# ['A3_site491.']
# 144000
# ['A3_site492.']
# 144000
# ['A3_site493.']
# 144000
# ['A3_site494.']
# 144000
# ['A3_site495.']
# 144000
# ['A3_site496.']
# 144000
# ['A3_site497.']
# 144000
# ['A3_site498.']
# 144000
# ['A3_site499.']
# 144000
# ['A3_site500.']
# 144000
# ['A3_site501.']
# 144000
# ['A3_site502.']
# 144000
# ['A3_site503.']
# 144000
# ['A3_site504.']
# 144000
# ['A3_site505.']
# 144000
# ['A3_site506.']
# 144000
# ['A3_site507.']
# 144000
# ['A3_site508.']
# 144000
# ['A3_site509.']
# 144000
# ['A3_site510.']
# 144000
# ['A3_site511.']
# 144000
# ['A3_site512.']
# 144000
# ['A3_site513.']
# 144000
# ['A3_site514.']
# 144000
# ['A3_site515.']
# 144000
# ['A3_site516.']
# 144000
# ['A3_site517.']
# 144000
# ['A3_site518.']
# 144000
# ['A3_site519.']
# 144000
# ['A3_site520.']
# 144000
# ['A3_site521.']
# 144000
# ['A3_site522.']
# 144000
# ['A3_site523.']
# 144000
# ['A3_site524.']
# 144000
# ['A3_site525.']
# 144000
# ['A3_site526.']
# 144000
# ['A3_site527.']
# 144000
# ['A3_site528.']
# 144000
# ['A3_site529.']
# 144000
# ['A3_site530.']
# 144000
# ['A3_site531.']
# 144000
# ['A3_site532.']
# 144000
# ['A3_site533.']
# 144000
# ['A3_site534.']
# 144000
# ['A3_site535.']
# 144000
# ['A3_site536.']
# 144000
# ['A3_site537.']
# 144000
# ['A3_site538.']
# 144000
# ['A3_site539.']
# 144000
# ['A3_site540.']
# 144000
# ['A3_site541.']
# 144000
# ['A3_site542.']
# 144000
# ['A3_site543.']
# 144000
# ['A3_site544.']
# 144000
# ['A3_site545.']
# 144000
# ['A3_site546.']
# 144000
# ['A3_site547.']
# 144000
# ['A3_site548.']
# 144000
# ['A3_site549.']
# 144000
# ['A3_site550.']
# 144000
# ['A3_site551.']
# 144000
# ['A3_site552.']
# 144000
# ['A3_site553.']
# 144000
# ['A3_site554.']
# 144000
# ['A3_site555.']
# 144000
# ['A3_site556.']
# 144000
# ['A3_site557.']
# 144000
# ['A3_site558.']
# 144000
# ['A3_site559.']
# 144000
# ['A3_site560.']
# 144000
# ['A3_site561.']
# 144000
# ['A3_site562.']
# 144000
# ['A3_site563.']
# 144000
# ['A3_site564.']
# 144000
# ['A3_site565.']
# 144000
# ['A3_site566.']
# 144000
# ['A3_site567.']
# 144000
# ['A3_site568.']
# 144000
# ['A3_site569.']
# 144000
# ['A3_site570.']
# 144000
# ['A3_site571.']
# 144000
# ['A3_site572.']
# 144000
# ['A3_site573.']
# 144000
# ['A3_site574.']
# 144000
# ['A3_site575.']
# 144000
# ['A3_site576.']
# 144000
# ['A3_site577.']
# 144000
# ['A3_site578.']
# 144000
# ['A3_site579.']
# 144000
# ['A3_site580.']
# 144000
# ['A3_site581.']
# 144000
# ['A3_site582.']
# 144000
# ['A3_site583.']
# 144000
# ['A3_site584.']
# 144000
# ['A3_site585.']
# 144000
# ['A3_site586.']
# 144000
# ['A3_site587.']
# 144000
# ['A3_site588.']
# 144000
# ['A3_site589.']
# 144000
# ['A3_site590.']
# 144000
# ['A3_site591.']
# 144000
# ['A3_site592.']
# 144000
# ['A3_site593.']
# 144000
# ['A3_site594.']
# 144000
# ['A3_site595.']
# 144000
# ['A3_site596.']
# 144000
# ['A3_site597.']
# 144000
# ['A3_site598.']
# 144000
# ['A3_site599.']
# 144000
# ['A3_site600.']
# 144000
# ['A3_site601.']
# 144000
# ['A3_site602.']
# 144000
# ['A3_site603.']
# 144000
# ['A3_site604.']
# 144000
# ['A3_site605.']
# 144000
# ['A3_site606.']
# 144000
# ['A3_site607.']
# 144000
# ['A3_site608.']
# 144000
# ['A3_site609.']
# 144000
# ['A3_site610.']
# 144000
# ['A3_site611.']
# 144000
# ['A3_site612.']
# 144000
# ['A3_site613.']
# 144000
# ['A3_site614.']
# 144000
# ['A3_site615.']
# 144000
# ['A3_site616.']
# 144000
# ['A3_site617.']
# 144000
# ['A3_site618.']
# 144000
# ['A3_site619.']
# 144000
# ['A3_site620.']
# 144000
# ['A3_site621.']
# 144000
# ['A3_site622.']
# 144000
# ['A3_site623.']
# 144000
# ['A3_site624.']
# 144000
# ['A3_site625.']
# 144000
# ['A3_site626.']
# 144000
# ['A3_site627.']
# 144000
# ['A3_site628.']
# 144000
# ['A3_site629.']
# 144000
# ['A3_site630.']
# 144000
# ['A3_site631.']
# 144000
# ['A3_site632.']
# 144000
# ['A3_site633.']
# 144000
# ['A3_site634.']
# 144000
# ['A3_site635.']
# 144000
# ['A3_site636.']
# 144000
# ['A3_site637.']
# 144000
# ['A3_site638.']
# 144000
# ['A3_site639.']
# 144000
# ['A3_site640.']
# 144000
# ['A3_site641.']
# 144000
# ['A3_site642.']
# 144000
# ['A3_site643.']
# 144000
# ['A3_site644.']
# 144000
# ['A3_site645.']
# 144000
# ['A3_site646.']
# 144000
# ['A3_site647.']
# 144000
# ['A3_site648.']
# 144000
# ['A3_site649.']
# 144000
# ['A3_site650.']
# 144000
# ['A3_site651.']
# 144000
# ['A3_site652.']
# 144000
# ['A3_site653.']
# 144000
# ['A3_site654.']
# 144000
# ['A3_site655.']
# 144000
# ['A3_site656.']
# 144000
# ['A3_site657.']
# 144000
# ['A3_site658.']
# 144000
# ['A3_site659.']
# 144000
# ['A3_site660.']
# 144000
# ['A3_site661.']
# 144000
# ['A3_site662.']
# 144000
# ['A3_site663.']
# 144000
# ['A3_site664.']
# 144000
# ['A3_site665.']
# 144000
# ['A3_site666.']
# 144000
# ['A3_site667.']
# 144000
# ['A3_site668.']
# 144000
# ['A3_site669.']
# 144000
# ['A3_site670.']
# 144000
# ['A3_site671.']
# 144000
# ['A3_site672.']
# 144000
# ['A3_site673.']
# 144000
# ['A3_site674.']
# 144000
# ['A3_site675.']
# 144000
# ['A3_site676.']
# 144000
# ['A3_site677.']
# 144000
# ['A3_site678.']
# 144000
# ['A3_site679.']
# 144000
# ['A3_site680.']
# 144000
# ['A3_site681.']
# 144000
# ['A3_site682.']
# 144000
# ['A3_site683.']
# 144000
# ['A3_site684.']
# 144000
# ['A3_site685.']
# 144000
# ['A3_site686.']
# 144000
# ['A3_site687.']
# 144000
# ['A3_site688.']
# 144000
# ['A3_site689.']
# 144000
# ['A3_site690.']
# 144000
# ['A3_site691.']
# 144000
# ['A3_site692.']
# 144000
# ['A3_site693.']
# 144000
# ['A3_site694.']
# 144000
# ['A3_site695.']
# 144000
# ['A3_site696.']
# 144000
# ['A3_site697.']
# 144000
# ['A3_site698.']
# 144000
# ['A3_site699.']
# 144000
# ['A3_site700.']
# 144000
# ['A3_site701.']
# 144000
# ['A3_site702.']
# 144000
# ['A3_site703.']
# 144000
# ['A3_site704.']
# 144000
# ['A3_site705.']
# 144000
# ['A3_site706.']
# 144000
# ['A3_site707.']
# 144000
# ['A3_site708.']
# 144000
# ['A3_site709.']
# 144000
# ['A3_site710.']
# 144000
# ['A3_site711.']
# 144000
# ['A3_site712.']
# 144000
# ['A3_site713.']
# 144000
# ['A3_site714.']
# 144000
# ['A3_site715.']
# 144000
# ['A3_site716.']
# 144000
# ['A3_site717.']
# 144000
# ['A3_site718.']
# 144000
# ['A3_site719.']
# 144000
# ['A3_site720.']
# 144000
# ['A3_site721.']
# 144000
# ['A3_site722.']
# 144000
# ['A3_site723.']
# 144000
# ['A3_site724.']
# 144000
# ['A3_site725.']
# 144000
# ['A3_site726.']
# 144000
# ['A3_site727.']
# 144000
# ['A3_site728.']
# 144000
# ['A3_site729.']
# 144000
# ['A3_site730.']
# 144000
# ['A3_site731.']
# 144000
# ['A3_site732.']
# 144000
# ['A3_site733.']
# 144000
# ['A3_site734.']
# 144000
# ['A3_site735.']
# 144000
# ['A3_site736.']
# 144000
# ['A3_site737.']
# 144000
# ['A3_site738.']
# 144000
# ['A3_site739.']
# 144000
# ['A3_site740.']
# 144000
# ['A3_site741.']
# 144000
# ['A3_site742.']
# 144000
# ['A3_site743.']
# 144000
# ['A3_site744.']
# 144000
# ['A3_site745.']
# 144000
# ['A3_site746.']
# 144000
# ['A3_site747.']
# 144000
# ['A3_site748.']
# 144000
# ['A3_site749.']
# 144000
# ['A3_site750.']
# 144000
# ['A3_site751.']
# 144000
# ['A3_site752.']
# 144000
# ['A3_site753.']
# 144000
# ['A3_site754.']
# 144000
# ['A3_site755.']
# 144000
# ['A3_site756.']
# 144000
# ['A3_site757.']
# 144000
# ['A3_site758.']
# 144000
# ['A3_site759.']
# 144000
# ['A3_site760.']
# 144000
# ['A3_site761.']
# 144000
# ['A3_site762.']
# 144000
# ['A3_site763.']
# 144000
# ['A3_site764.']
# 144000
# ['A3_site765.']
# 144000
# ['A3_site766.']
# 144000
# ['A3_site767.']
# 144000
# ['A3_site768.']
# 144000
# ['A3_site769.']
# 144000
# ['A3_site770.']
# 144000
# ['A3_site771.']
# 144000
# ['A3_site772.']
# 144000
# ['A3_site773.']
# 144000
# ['A3_site774.']
# 144000
# ['A3_site775.']
# 144000
# ['A3_site776.']
# 144000
# ['A3_site777.']
# 144000
# ['A3_site778.']
# 144000
# ['A3_site779.']
# 144000
# ['A3_site780.']
# 144000
# ['A3_site781.']
# 144000
# ['A3_site782.']
# 144000
# ['A3_site783.']
# 144000
# ['A3_site784.']
# 144000
# ['A3_site785.']
# 144000
# ['A3_site786.']
# 144000
# ['A3_site787.']
# 144000
# ['A3_site788.']
# 144000
# ['A3_site789.']
# 144000
# ['A3_site790.']
# 144000
# ['A3_site791.']
# 144000
# ['A3_site792.']
# 144000
# ['A3_site793.']
# 144000
# ['A3_site794.']
# 144000
# ['A3_site795.']
# 144000
# ['A3_site796.']
# 144000
# ['A3_site797.']
# 144000
# ['A3_site798.']
# 144000
# ['A3_site799.']
# 144000
# ['A3_site800.']
# 144000
# ['A3_site801.']
# 144000
# ['A3_site802.']
# 144000
# ['A3_site803.']
# 144000
# ['A3_site804.']
# 144000
# ['A3_site805.']
# 144000
# ['A3_site806.']
# 144000
# ['A3_site807.']
# 144000
# ['A3_site808.']
# 144000
# ['A3_site809.']
# 144000
# ['A3_site810.']
# 144000
# ['A3_site811.']
# 144000
# ['A3_site812.']
# 144000
# ['A3_site813.']
# 144000
# ['A3_site814.']
# 144000
# ['A3_site815.']
# 144000
# ['A3_site816.']
# 144000
# ['A3_site817.']
# 144000
# ['A3_site818.']
# 144000
# ['A3_site819.']
# 144000
# ['A3_site820.']
# 144000
# ['A3_site821.']
# 144000
# ['A3_site822.']
# 144000
# ['A3_site823.']
# 144000
# ['A3_site824.']
# 144000
# ['A3_site825.']
# 144000
# ['A3_site826.']
# 144000
# ['A3_site827.']
# 144000
# ['A3_site828.']
# 144000
# ['A3_site829.']
# 144000
# ['A3_site830.']
# 144000
# ['A3_site831.']
# 144000
# ['A3_site832.']
# 144000
# ['A3_site833.']
# 144000
# ['A3_site834.']
# 144000
# ['A3_site835.']
# 144000
# ['A3_site836.']
# 144000
# ['A3_site837.']
# 144000
# ['A3_site838.']
# 144000
# ['A3_site839.']
# 144000
# ['A3_site840.']
# 144000
# ['A3_site841.']
# 144000
# ['A3_site842.']
# 144000
# ['A3_site843.']
# 144000
# ['A3_site844.']
# 144000
# ['A3_site845.']
# 144000
# ['A3_site846.']
# 144000
# ['A3_site847.']
# 144000
# ['A3_site848.']
# 144000
# ['A3_site849.']
# 144000
# ['A3_site850.']
# 144000
# ['A3_site851.']
# 144000
# ['A3_site852.']
# 144000
# ['A3_site853.']
# 144000
# ['A3_site854.']
# 144000
# ['A3_site855.']
# 144000
# ['A3_site856.']
# 144000
# ['A3_site857.']
# 144000
# ['A3_site858.']
# 144000
# ['A3_site859.']
# 144000
# ['A3_site860.']
# 144000
# ['A3_site861.']
# 144000
# ['A3_site862.']
# 144000
# ['A3_site863.']
# 144000
# ['A3_site864.']
# 144000
# ['A3_site865.']
# 144000
# ['A3_site866.']
# 144000
# ['A3_site867.']
# 144000
# ['A3_site868.']
# 144000
# ['A3_site869.']
# 144000
# ['A3_site870.']
# 144000
# ['A3_site871.']
# 144000
# ['A3_site872.']
# 144000
# ['A3_site873.']
# 144000
# ['A3_site874.']
# 144000
# ['A3_site875.']
# 144000
# ['A3_site876.']
# 144000
# ['A3_site877.']
# 144000
# ['A3_site878.']
# 144000
# ['A3_site879.']
# 144000
# ['A3_site880.']
# 144000
# ['A3_site881.']
# 144000
# ['A3_site882.']
# 144000
# ['A3_site883.']
# 144000
# ['A3_site884.']
# 144000
# ['A3_site885.']
# 144000
# ['A3_site886.']
# 144000
# ['A3_site887.']
# 144000
# ['A3_site888.']
# 144000
# ['A3_site889.']
# 144000
# ['A3_site890.']
# 144000
# ['A3_site891.']
# 144000
# ['A3_site892.']
# 144000
# ['A3_site893.']
# 144000
# ['A3_site894.']
# 144000
# ['A3_site895.']
# 144000
# ['A3_site896.']
# 144000
# ['A3_site897.']
# 144000
# ['A3_site898.']
# 144000
# ['A3_site899.']
# 144000
# ['A3_site900.']
# 144000
# ['A3_site901.']
# 144000
# ['A3_site902.']
# 144000
# ['A3_site903.']
# 144000
# ['A3_site904.']
# 144000
# ['A3_site905.']
# 144000
# ['A3_site906.']
# 144000
# ['A3_site907.']
# 144000
# ['A3_site908.']
# 144000
# ['A3_site909.']
# 144000
# ['A3_site910.']
# 144000
# ['A3_site911.']
# 144000
# ['A3_site912.']
# 144000
# ['A3_site913.']
# 144000
# ['A3_site914.']
# 144000
# ['A3_site915.']
# 144000
# ['A3_site916.']
# 144000
# ['A3_site917.']
# 144000
# ['A3_site918.']
# 144000
# ['A3_site919.']
# 144000
# ['A3_site920.']
# 144000
# ['A3_site921.']
# 144000
# ['A3_site922.']
# 144000
# ['A3_site923.']
# 144000
# ['A3_site924.']
# 144000
# ['A3_site925.']
# 144000
# ['A3_site926.']
# 144000
# ['A3_site927.']
# 144000
# ['A3_site928.']
# 144000
# ['A3_site929.']
# 144000
# ['A3_site930.']
# 144000
# ['A3_site931.']
# 144000
# ['A3_site932.']
# 144000
# ['A3_site933.']
# 144000
# ['A3_site934.']
# 144000
# ['A3_site935.']
# 144000
# ['A3_site936.']
# 144000
# ['A3_site937.']
# 144000
# ['A3_site938.']
# 144000
# ['A3_site939.']
# 144000
# ['A3_site940.']
# 144000
# ['A3_site941.']
# 144000
# ['A3_site942.']
# 144000
# ['A3_site943.']
# 144000
# ['A3_site944.']
# 144000
# ['A3_site945.']
# 144000
# ['A3_site946.']
# 144000
# ['A3_site947.']
# 144000
# ['A3_site948.']
# 144000
# ['A3_site949.']
# 144000
# ['A3_site950.']
# 144000
# ['A3_site951.']
# 144000
# ['A3_site952.']
# 144000
# ['A3_site953.']
# 144000
# ['A3_site954.']
# 144000
# ['A3_site955.']
# 144000
# ['A3_site956.']
# 144000
# ['A3_site957.']
# 144000
# ['A3_site958.']
# 144000
# ['A3_site959.']
# 144000
# ['A3_site960.']
# 144000
# ['A3_site961.']
# 144000
# ['A3_site962.']
# 144000
# ['A3_site963.']
# 144000
# ['A3_site964.']
# 144000
# ['A3_site965.']
# 144000
# ['A3_site966.']
# 144000
# ['A3_site967.']
# 144000
# ['A3_site968.']
# 144000
# ['A3_site969.']
# 144000
# ['A3_site970.']
# 144000
# ['A3_site971.']
# 144000
# ['A3_site972.']
# 144000
# ['A3_site973.']
# 144000
# ['A3_site974.']
# 144000
# ['A3_site975.']
# 144000
# ['A3_site976.']
# 144000
# ['A3_site977.']
# 144000
# ['A3_site978.']
# 144000
# ['A3_site979.']
# 144000
# ['A3_site980.']
# 144000
# ['A3_site981.']
# 144000
# ['A3_site982.']
# 144000
# ['A3_site983.']
# 144000
# ['A3_site984.']
# 144000
# ['A3_site985.']
# 144000
# ['A3_site986.']
# 144000
# ['A3_site987.']
# 144000
# ['A3_site988.']
# 144000
# ['A3_site989.']
# 144000
# ['A3_site990.']
# 144000
# ['A3_site991.']
# 144000
# ['A3_site992.']
# 144000
# ['A3_site993.']
# 144000
# ['A3_site994.']
# 144000
# ['A3_site995.']
# 144000
# ['A3_site996.']
# 144000
# ['A3_site997.']
# 144000
# ['A3_site998.']
# 144000
# ['A3_site999.']
# 144000
# ['A3_site1000.']
# 144000
# ['A3_site1001.']
# 144000
# ['A3_site1002.']
# 144000
# ['A3_site1003.']
# 144000
# ['A3_site1004.']
# 144000
# ['A3_site1005.']
# 144000
# ['A3_site1006.']
# 144000
# ['A3_site1007.']
# 144000
# ['A3_site1008.']
# 144000
# ['A3_site1009.']
# 144000
# ['A3_site1010.']
# 144000
# ['A3_site1011.']
# 144000
# ['A3_site1012.']
# 144000
# ['A3_site1013.']
# 144000
# ['A3_site1014.']
# 144000
# ['A3_site1015.']
# 144000
# ['A3_site1016.']
# 144000
# ['A3_site1017.']
# 144000
# ['A3_site1018.']
# 144000
# ['A3_site1019.']
# 144000
# ['A3_site1020.']
# 144000
# ['A3_site1021.']
# 144000
# ['A3_site1022.']
# 144000
# ['A3_site1023.']
# 144000
# ['A3_site1024.']
# 144000
# ['A3_site1025.']
# 144000
# ['A3_site1026.']
# 144000
# ['A3_site1027.']
# 144000
# ['A3_site1028.']
# 144000
# ['A3_site1029.']
# 144000
# ['A3_site1030.']
# 144000
# ['A3_site1031.']
# 144000
# ['A3_site1032.']
# 144000
# ['A3_site1033.']
# 144000
# ['A3_site1034.']
# 144000
# ['A3_site1035.']
# 144000
# ['A3_site1036.']
# 144000
# ['A3_site1037.']
# 144000
# ['A3_site1038.']
# 144000
# ['A3_site1039.']
# 144000
# ['A3_site1040.']
# 144000
# ['A3_site1041.']
# 144000
# ['A3_site1042.']
# 144000
# ['A3_site1043.']
# 144000
# ['A3_site1044.']
# 144000
# ['A3_site1045.']
# 144000
# ['A3_site1046.']
# 144000
# ['A3_site1047.']
# 144000
# ['A3_site1048.']
# 144000
# ['A3_site1049.']
# 144000
# ['A3_site1050.']
# 144000
# ['A3_site1051.']
# 144000
# ['A3_site1052.']
# 144000
# ['A3_site1053.']
# 144000
# ['A3_site1054.']
# 144000
# ['A3_site1055.']
# 144000
# ['A3_site1056.']
# 144000
# ['A3_site1057.']
# 144000
# ['A3_site1058.']
# 144000
# ['A3_site1059.']
# 144000
# ['A3_site1060.']
# 144000
# ['A3_site1061.']
# 144000
# ['A3_site1062.']
# 144000
# ['A3_site1063.']
# 144000
# ['A3_site1064.']
# 144000
# ['A3_site1065.']
# 144000
# ['A3_site1066.']
# 144000
# ['A3_site1067.']
# 144000
# ['A3_site1068.']
# 144000
# ['A3_site1069.']
# 144000
# ['A3_site1070.']
# 144000
# ['A3_site1071.']
# 144000
# ['A3_site1072.']
# 144000
# ['A3_site1073.']
# 144000
# ['A3_site1074.']
# 144000
# ['A3_site1075.']
# 144000
# ['A3_site1076.']
# 144000
# ['A3_site1077.']
# 144000
# ['A3_site1078.']
# 144000
# ['A3_site1079.']
# 144000
# ['A3_site1080.']
# 144000
# ['A3_site1081.']
# 144000
# ['A3_site1082.']
# 144000
# ['A3_site1083.']
# 144000
# ['A3_site1084.']
# 144000
# ['A3_site1085.']
# 144000
# ['A3_site1086.']
# 144000
# ['A3_site1087.']
# 144000
# ['A3_site1088.']
# 144000
# ['A3_site1089.']
# 144000
# ['A3_site1090.']
# 144000
# ['A3_site1091.']
# 144000
# ['A3_site1092.']
# 144000
# ['A3_site1093.']
# 144000
# ['A3_site1094.']
# 144000
# ['A3_site1095.']
# 144000
# ['A3_site1096.']
# 144000
# ['A3_site1097.']
# 144000
# ['A3_site1098.']
# 144000
# ['A3_site1099.']
# 144000
# ['A3_site1100.']
# 144000
# ['A3_site1101.']
# 144000
# ['A3_site1102.']
# 144000
# ['A3_site1103.']
# 144000
# ['A3_site1104.']
# 144000
# ['A3_site1105.']
# 144000
# ['A3_site1106.']
# 144000
# ['A3_site1107.']
# 144000
# ['A3_site1108.']
# 144000
# ['A3_site1109.']
# 144000
# ['A3_site1110.']
# 144000
# ['A3_site1111.']
# 144000
# ['A3_site1112.']
# 144000
# ['A3_site1113.']
# 144000
# ['A3_site1114.']
# 144000
# ['A3_site1115.']
# 144000
# ['A3_site1116.']
# 144000
# ['A3_site1117.']
# 144000
# ['A3_site1118.']
# 144000
# ['A3_site1119.']
# 144000
# ['A3_site1120.']
# 144000
# ['A3_site1121.']
# 144000
# ['A3_site1122.']
# 144000
# ['A3_site1123.']
# 144000
# ['A3_site1124.']
# 144000
# ['A3_site1125.']
# 144000
# ['A3_site1126.']
# 144000
# ['A3_site1127.']
# 144000
# ['A3_site1128.']
# 144000
# ['A3_site1129.']
# 144000
# ['A3_site1130.']
# 144000
# ['A3_site1131.']
# 144000
# ['A3_site1132.']
# 144000
# ['A3_site1133.']
# 144000
# ['A3_site1134.']
# 144000
# ['A3_site1135.']
# 144000
# ['A3_site1136.']
# 144000
# ['A3_site1137.']
# 144000
# ['A3_site1138.']
# 144000
# ['A3_site1139.']
# 144000
# ['A3_site1140.']
# 144000
# ['A3_site1141.']
# 144000
# ['A3_site1142.']
# 144000
# ['A3_site1143.']
# 144000
# ['A3_site1144.']
# 144000
# ['A3_site1145.']
# 144000
# ['A3_site1146.']
# 144000
# ['A3_site1147.']
# 144000
# ['A3_site1148.']
# 144000
# ['A3_site1149.']
# 144000
# ['A3_site1150.']
# 144000
# ['A3_site1151.']
# 144000
# ['A3_site1152.']
# 144000
# ['A3_site1153.']
# 144000
# ['A3_site1154.']
# 144000
# ['A3_site1155.']
# 144000
# ['A3_site1156.']
# 144000
# ['A3_site1157.']
# 144000
# ['A3_site1158.']
# 144000
# ['A3_site1159.']
# 144000
# ['A3_site1160.']
# 144000
# ['A3_site1161.']
# 144000
# ['A3_site1162.']
# 144000
# ['A3_site1163.']
# 144000
# ['A3_site1164.']
# 144000
# ['A3_site1165.']
# 144000
# ['A3_site1166.']
# 144000
# ['A3_site1167.']
# 144000
# ['A3_site1168.']
# 144000
# ['A3_site1169.']
# 144000
# ['A3_site1170.']
# 144000
# ['A3_site1171.']
# 144000
# ['A3_site1172.']
# 144000
# ['A3_site1173.']
# 144000
# ['A3_site1174.']
# 144000
# ['A3_site1175.']
# 144000
# ['A3_site1176.']
# 144000
# ['A3_site1177.']
# 144000
# ['A3_site1178.']
# 144000
# ['A3_site1179.']
# 144000
# ['A3_site1180.']
# 144000
# ['A3_site1181.']
# 144000
# ['A3_site1182.']
# 144000
# ['A3_site1183.']
# 144000
# ['A3_site1184.']
# 144000
# ['A3_site1185.']
# 144000
# ['A3_site1186.']
# 144000
# ['A3_site1187.']
# 144000
# ['A3_site1188.']
# 144000
# ['A3_site1189.']
# 144000
# ['A3_site1190.']
# 144000
# ['A3_site1191.']
# 144000
# ['A3_site1192.']
# 144000
# ['A3_site1193.']
# 144000
# ['A3_site1194.']
# 144000
# ['A3_site1195.']
# 144000
# ['A3_site1196.']
# 144000
# ['A3_site1197.']
# 144000
# ['A3_site1198.']
# 144000
# ['A3_site1199.']
# 144000
# ['A3_site1200.']
# 144000
# ['A3_site1201.']
# 144000
# ['A3_site1202.']
# 144000
# ['A3_site1203.']
# 144000
# ['A3_site1204.']
# 144000
# ['A3_site1205.']
# 144000
# ['A3_site1206.']
# 144000
# ['A3_site1207.']
# 144000
# ['A3_site1208.']
# 144000
# ['A3_site1209.']
# 144000
# ['A3_site1210.']
# 144000
# ['A3_site1211.']
# 144000
# ['A3_site1212.']
# 144000
# ['A3_site1213.']
# 144000
# ['A3_site1214.']
# 144000
# ['A3_site1215.']
# 144000
# ['A3_site1216.']
# 144000
# ['A3_site1217.']
# 144000
# ['A3_site1218.']
# 144000
# ['A3_site1219.']
# 144000
# ['A3_site1220.']
# 144000
# ['A3_site1221.']
# 144000
# ['A3_site1222.']
# 144000
# ['A3_site1223.']
# 144000
# ['A3_site1224.']
# 144000
# ['A3_site1225.']
# 144000
# ['A3_site1226.']
# 144000
# ['A3_site1227.']
# 144000
# ['A3_site1228.']
# 144000
# ['A3_site1229.']
# 144000
# ['A3_site1230.']
# 144000
# ['A3_site1231.']
# 144000
# ['A3_site1232.']
# 144000
# ['A3_site1233.']
# 144000
# ['A3_site1234.']
# 144000
# ['A3_site1235.']
# 144000
# ['A3_site1236.']
# 144000
# ['A3_site1237.']
# 144000
# ['A3_site1238.']
# 144000
# ['A3_site1239.']
# 144000
# ['A3_site1240.']
# 144000
# ['A3_site1241.']
# 144000
# ['A3_site1242.']
# 144000
# ['A3_site1243.']
# 144000
# ['A3_site1244.']
# 144000
# ['A3_site1245.']
# 144000
# ['A3_site1246.']
# 144000
# ['A3_site1247.']
# 144000
# ['A3_site1248.']
# 144000
# ['A3_site1249.']
# 144000
# ['A3_site1250.']
# 144000
# ['A3_site1251.']
# 144000
# ['A3_site1252.']
# 144000
# ['A3_site1253.']
# 144000
# ['A3_site1254.']
# 144000
# ['A3_site1255.']
# 144000
# ['A3_site1256.']
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# (43, 14)
# 144041
# ['A3_site1257.']
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# (151, 14)
# 144192
# ['A3_site1258.']
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# (332, 14)
# 144523
# ['A3_site1259.']
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# (105, 14)
# 144628
# ['A3_site1260.']
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# (372, 14)
# 144999
# ['A3_site1261.']
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# 145027
# ['A3_site1262.']
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# (30, 14)
# 145057
# ['A3_site1263.']
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# (139, 14)
# 145195
# ['A3_site1264.']
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# 145209
# ['A3_site1265.']
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# (94, 14)
# 145301
# ['A3_site1266.']
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# (13, 14)
# 145314
# ['A3_site1267.']
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# (46, 14)
# 145360
# ['A3_site1268.']
# 145360
# ['A3_site1269.']
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# (27, 14)
# 145387
# ['A3_site1270.']
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# 145415
# ['A3_site1271.']
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# (115, 14)
# 145530
# ['A3_site1272.']
# 145530
# ['A3_site1273.']
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# 145554
# ['A3_site1274.']
# 145554
# ['A3_site1275.']
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# (28, 14)
# 145581
# ['A3_site1276.']
# 145581
# ['A3_site1277.']
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# (54, 14)
# 145635
# ['A3_site1278.']
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# (24, 14)
# 145659
# ['A3_site1279.']
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# (164, 14)
# saving last site and cell
# (1822, 7, 299, 299)
# 145822
# ['A3_site1280.']

# %%
import gc

# takes about 7min/ch

files =  natsorted(glob('/home/rcarlson/mountb/m40-m42/process/single_cells/*M40A*166000_168000*B2*.tif'))[-1:]
for file in files:
    channel = file.split('ch')[1][0]
    print('ch: ', channel)
    plate = file.split('/')[-1].split('_')[0]
    well = file.split('/')[-1].split('_')[3]
    start = file.split('/')[-1].split('_')[1]
    end = file.split('/')[-1].split('_')[2]

    print(start, end, plate, well)
    batch_preprocess_predict(file, start=start,end=end, plate=plate, well=well) ## 
    gc.collect()
    
    
    ## 38 - 1-2 left.
# Out:
# ch:  6
# 166000 168000 M40A B2
# /home/rcarlson/mountb/m40-m42/process/single_cells/M40A_166000_168000_B2_Site-1184.ch6.tif
# (2000, 299, 299)
# mean, sd
# 5533.593 2533.048
# 0
# 500
# 1000
# 1500
# preprocessing done
# 2000
# tf dataset created
# 2000/2000 [==============================] - 101s 48ms/step
